# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from math import exp
from scipy.stats import norm
from scipy import stats
import seaborn as sns
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('kc_house_data_train.csv', index_col=0)

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      2591820310  20141006T000000   365000.0         4       2.25
# 1      7974200820  20140821T000000   865000.0         5       3.00
# 2      7701450110  20140815T000000  1038000.0         4       2.50
# 3      9522300010  20150331T000000  1490000.0         3       3.50
# 4      9510861140  20140714T000000   711000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 17285   627300195  20150303T000000   750000.0         5       2.50
# 17286  8819900270  20140520T000000   440000.0         2       1.75
# 17287  3816300095  20140514T000000   310000.0         3       1.00
# 17288   122069107  20141204T000000   427500.0         3       1.50
# 17289  6703100135  20150116T000000   348000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             2070      8893     2.0           0     0  ...      8
# ...

# %%
df['ren_age'] =  df['yr_renovated'].map(lambda x: 2015-x)

# %%
df['ren_age'].value_counts()
# Out:
# 2015    16564
# 1          71
# 10         32
# 8          32
# 15         31
#         ...
# 67          1
# 81          1
# 56          1
# 64          1
# 71          1
# Name: ren_age, Length: 69, dtype: int64

# %%
ren_age_dict = {2015:0}
df['ren_age'] = df['ren_age'].replace(ren_age_dict)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'ren_age',
#        'bedrooms_scaled', 'bathrooms_scaled', 'sqft_living_scaled',
#        'long_scaled', 'yr_built_scaled', 'condition_scaled', 'price_scaled'],
#       dtype='object')

# %%
# import matplotlib.pyplot as plt
# %matplotlib inline
# import numpy as np

# fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(16,3))

# for xcol, ax in zip(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#                     'grade', 'sqft_above', 'sqft_basement',  'yr_built', 'zipcode', 'lat', 'long'], axes):
#     df.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha=0.4, color='b')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'ren_age'],
#       dtype='object')

# %%
features = df[['bedrooms', 'bathrooms', 'sqft_living', 'long', 'yr_built', 'condition']]

# %%
feature_list = ['bedrooms', 'bathrooms', 'sqft_living', 'long', 'yr_built', 'condition']

# %%
from statsmodels.formula.api import ols

# %%
lr_model = ols(formula='price~bedrooms+bathrooms+long+yr_built+condition', data=df).fit()
lr_model1 = ols(formula='price_scaled~bedrooms_scaled+bathrooms_scaled+long_scaled+yr_built_scaled+condition_scaled', data=df).fit()

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     1741.
# Date:                Wed, 19 Feb 2020   Prob (F-statistic):               0.00
# Time:                        14:40:26   Log-Likelihood:            -2.4284e+05
# No. Observations:               17290   AIC:                         4.857e+05
# Df Residuals:                   17284   BIC:                         4.857e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.078e+05   2.29e+06      0.353      0.724   -3.68e+06     5.3e+06
# ...

# %%
lr_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           price_scaled   R-squared:                       0.335
# Model:                            OLS   Adj. R-squared:                  0.335
# Method:                 Least Squares   F-statistic:                     1741.
# Date:                Wed, 19 Feb 2020   Prob (F-statistic):               0.00
# Time:                        14:40:34   Log-Likelihood:                -21008.
# No. Observations:               17290   AIC:                         4.203e+04
# Df Residuals:                   17284   BIC:                         4.207e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_features = scaler.fit(features)

# %%
scaled_features
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
feature_list

feature_scaled = []
for var in feature_list:
    new_col = var +"_scaled"
    df[new_col] = scaler.fit_transform(df[[var]])
    feature_scaled.append(new_col)

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      2591820310  20141006T000000   365000.0         4       2.25
# 1      7974200820  20140821T000000   865000.0         5       3.00
# 2      7701450110  20140815T000000  1038000.0         4       2.50
# 3      9522300010  20150331T000000  1490000.0         3       3.50
# 4      9510861140  20140714T000000   711000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 17285   627300195  20150303T000000   750000.0         5       2.50
# 17286  8819900270  20140520T000000   440000.0         2       1.75
# 17287  3816300095  20140514T000000   310000.0         3       1.00
# 17288   122069107  20141204T000000   427500.0         3       1.50
# 17289  6703100135  20150116T000000   348000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_living15  \
# 0             2070      8893     2.0           0     0  ...           2390
# ...

# %%
target = ['price']
target
# Out:
# ['price']

# %%
target

target_scaled = []
for var in target:
    new_col = var +"_scaled"
    df[new_col] = scaler.fit_transform(df[[var]])
    target_scaled.append(new_col)
