# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Load our dataframe account for the index columns
df = pd.read_csv('case_study.csv', index_col = 0 )
# Out:
# /Users/flatironschool/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (171) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Quickly check to see the size of our DF, both rows and columns
df.head()
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# 49938       2.0       1.0       1.0       NaN       NaN       1.0
# 49939       1.0       2.0       2.0       NaN       NaN       2.0
# 49940       2.0       1.0       1.0       NaN       NaN       2.0
# 49941       2.0       1.0       1.0       NaN       NaN       1.0
# 49942       1.0       1.0       1.0       NaN       NaN       2.0
#
# [5 rows x 358 columns]

# %%
df.shape
# Out:
# (34545, 358)

# %% [markdown]
# ## Subset your dataframe to only include the states in the tri-state area (NJ, CT, NY)

# %%
# your code here
#lhow many missing values are there

df.isnull().sum()
# Out:
# _STATE          0
# FMONTH          0
# IDATE           0
# IMONTH          0
# IDAY            0
#             ...
# _RFSEAT2        0
# _RFSEAT3        0
# _FLSHOT6    22334
# _PNEUMO2    22334
# _AIDTST3     3773
# Length: 358, dtype: int64

# %% [markdown]
# Now check to see how large our subset df.

# %%
# your code here

# %% [markdown]
# **PHYSHLTH** is the column we are interested in for this analysis, so let's start to investigate the column. Since we have a data cookbook, a.k.a. data dictionary) we want to start there before looking at the code.

# %%
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 1. Handle the non-normal values
#
# As you can see from the data dictionary, there are a number of responses that are coded with values that could throw off our descriptive statistics.  Let's clean up by mapping the responses to a more appropriate value, and handling any missing values.

# %%
#your code here
#create a list of columns that don't have any values


list_of_dropped_columns = []
for col in df.columns:
    if df[col].isna().sum() == len(df):
        list_of_dropped_columns.append(col)

# %%
clean_df = df.drop(columns=list_of_dropped_columns)

# %%
#looking at sick days, hiw many people fall into each category of number of sick days
clean_df['PHYSHLTH'].value_counts()
# Out:
# 88.0    21296
# 30.0     2438
# 2.0      1993
# 1.0      1538
# 3.0      1187
# 5.0      1092
# 10.0      751
# 7.0       641
# 15.0      640
# 4.0       622
# 77.0      493
# 20.0      402
# 14.0      326
# 99.0      305
# 6.0       187
# 25.0      159
# 8.0        99
# 21.0       70
# 12.0       69
# 28.0       57
# 29.0       35
# 27.0       22
# 18.0       19
# 16.0       16
# 17.0       15
# 9.0        15
# 22.0       12
# 13.0       10
# 19.0       10
# 11.0        8
# 24.0        7
# 26.0        7
# 23.0        4
# Name: PHYSHLTH, dtype: int64

# %%
#drop patients who refused to answer and we're not sure 
drop_list = []

for i in clean_df['PHYSHLTH']:
    if i == 99 or i == 77:
        drop_list.append(i)
drop_list
# Out:
# [77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  99.0,
#  77.0,
#  77.0,
#  99.0,
#  99.0]

# %%
len(drop_list)
# Out:
# 798

# %%
#remove thoses from the dataset


clean_df.drop(clean_df[clean_df['PHYSHLTH'] == 77 ].index , inplace=True)

# %%
clean_df.drop(clean_df[clean_df['PHYSHLTH'] == 99 ].index , inplace=True)

# %%
#look at the shape of the new, cleaned up DF
clean_df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean        59.617625
# std         37.706577
# min          1.000000
# 25%         14.000000
# 50%         88.000000
# 75%         88.000000
# max         88.000000
# Name: PHYSHLTH, dtype: float64

# %%
#change values for 88 to 0 to indicate 0 sick days
clean_df['PHYSHLTH']=clean_df['PHYSHLTH'].apply(lambda x: 0 if x==88 else x)

# %%
# #channge value labels for states to make it easier to read
clean_df['_STATE'] = clean_df['_STATE'].map({9.0:'Connecticut',34.0:'New Jersey', 36.0:'New York'})

# %%
#rename _STATE column to state
clean_df = clean_df.rename(columns={'_STATE':'state'})

# %%
#rename PHYSHLTH column to Num of Sick Days
clean_df = clean_df.rename(columns={'PHYSHLTH':'Num of Sick Days'})

# %%
clean_df['state'].value_counts()
# Out:
# New York       11876
# New Jersey     11458
# Connecticut    10413
# Name: state, dtype: int64

# %%
## 2. Generate the descriptive statistics

#Now that our target variable is cleaned up lets calculate the descriptive statistics, 
#generate a graph that quickly shows those statistics, and generate a gprah shows the histogram of the data.

clean_df['Num of Sick Days'].plot(kind='hist')

# %%
s2

# %% [markdown]
# ## 3. Generate a graphic that compares the average number of sick days for each state.

# %%
# code to calculate the average number of sick days by state
#merge state and sick day columns
s1 = pd.DataFrame(clean_df['state']).reset_index().drop(columns='index')
s2 = pd.DataFrame(clean_df['Num of Sick Days']).reset_index().drop(columns='index')
state_phyh = pd.concat([s2, s1], axis=1)

# %%
state_phyh = state_phyh.groupby('state')['Num of Sick Days'].mean()

# %%
state_phyh
# Out:
# state
# Connecticut    3.688562
# New Jersey     4.380957
# New York       4.148030
# Name: Num of Sick Days, dtype: float64

# %%
# code to graph those averages using matplotlib

state_phyh.plot(kind='bar', rot=45, title='Avg Sick Days per State')

# %%
fig,ax = plt.subplots()
plt.suptitle('Avg Sick Days per State')
ax = state_phyh.plot(kind='bar', rot=45)
ax.set_ylabel('Avg # Sick Days')
ax.set_xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# ## 4. Turn the number of sick days into a classification of of chronically sick people.
#
# Chronically sick people account for a significant proportion of the costs for health insurers. If we can identify what leads people to be chronically sick, we can address them with specific treatments.

# %%
clean_df
# Out:
#               state  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE  \
# 49938   Connecticut     5.0  5172017       5    17   2017    1200.0
# 49939   Connecticut     2.0  2142017       2    14   2017    1200.0
# 49940   Connecticut     1.0  1292017       1    29   2017    1200.0
# 49941   Connecticut     7.0  9112017       9    11   2017    1200.0
# 49942   Connecticut     5.0  7182017       7    18   2017    1200.0
# ...             ...     ...      ...     ...   ...    ...       ...
# 303774     New York     5.0  5152017       5    15   2017    1200.0
# 303775     New York     6.0  6252017       6    25   2017    1200.0
# 303776     New York     7.0  7212017       7    21   2017    1200.0
# 303777     New York     7.0  7202017       7    20   2017    1200.0
# 303778     New York     7.0  7252017       7    25   2017    1200.0
#
#              SEQNO          _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  \
# 49938   2017000001  2.017000e+09       NaN  ...       2.0       2.0       2.0
# 49939   2017000002  2.017000e+09       NaN  ...       1.0       1.0       1.0
# 49940   2017000003  2.017000e+09       NaN  ...       3.0       2.0       1.0
# 49941   2017000004  2.017000e+09       NaN  ...       2.0       2.0       2.0
# 49942   2017000005  2.017000e+09       NaN  ...       2.0       2.0       1.0
# ...            ...           ...       ...  ...       ...       ...       ...
# 303774  2017012245  2.017012e+09       NaN  ...       3.0       2.0       2.0
# 303775  2017012246  2.017012e+09       NaN  ...       2.0       2.0       2.0
# 303776  2017012247  2.017012e+09       NaN  ...       2.0       2.0       2.0
# 303777  2017012248  2.017012e+09       NaN  ...       9.0       9.0       9.0
# 303778  2017012249  2.017012e+09       NaN  ...       3.0       2.0       2.0
#
#         _PAREC1  _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# 49938       4.0       2.0       1.0       1.0       NaN       NaN       1.0
# 49939       1.0       1.0       2.0       2.0       NaN       NaN       2.0
# 49940       3.0       2.0       1.0       1.0       NaN       NaN       2.0
# 49941       2.0       2.0       1.0       1.0       NaN       NaN       1.0
# 49942       1.0       1.0       1.0       1.0       NaN       NaN       2.0
# ...         ...       ...       ...       ...       ...       ...       ...
# 303774      4.0       2.0       1.0       1.0       NaN       NaN       1.0
# 303775      4.0       2.0       1.0       1.0       NaN       NaN       1.0
# 303776      4.0       2.0       1.0       1.0       NaN       NaN       1.0
# 303777      9.0       9.0       9.0       9.0       9.0       9.0       9.0
# 303778      4.0       2.0       1.0       1.0       NaN       NaN       1.0
#
# [33747 rows x 258 columns]

# %%
# #rename columns for chronic illnesses
clean_df = clean_df.rename(columns=({'CVDINFR4':'Heart Attack', 'CVDCRHD4':'Heart Disease', 'CVDSTRK3':'Stroke', 'ASTHMA3':'Had Asthma',
                                     'ASTHNOW':'Have Asthma Now',
                                    'CHCSCNCR':'Skin Cancer', 'CHCOCNCR':'Other Cancer', 'CHCCOPD1':'Pulmonary,emphysema,bronchitis',
                                    'HAVARTH3':'Arthritis', 'ADDEPEV2':'Depression', 'CHCKIDNY':'Kidney Disease', 'DIABETE3':'Diabetes'}))

# %%
#slice dataframe for chronic illnesses
chronic_df = clean_df.loc[:, 'Heart Attack':'Diabetes']

# %%
#change 2.0 values to 0
chronic_df.replace(range(2,10),0, inplace=True)

# %%
chronic_df
# Out:
#         Heart Attack  Heart Disease  Stroke  Had Asthma  Have Asthma Now  \
# 49938            0.0            0.0     0.0         0.0              NaN
# 49939            0.0            0.0     0.0         0.0              NaN
# 49940            0.0            0.0     0.0         0.0              NaN
# 49941            0.0            0.0     0.0         0.0              NaN
# 49942            0.0            0.0     0.0         0.0              NaN
# ...              ...            ...     ...         ...              ...
# 303774           0.0            0.0     0.0         0.0              NaN
# 303775           0.0            0.0     0.0         0.0              NaN
# 303776           0.0            0.0     0.0         0.0              NaN
# 303777           0.0            0.0     0.0         0.0              NaN
# 303778           0.0            0.0     0.0         0.0              NaN
#
#         Skin Cancer  Other Cancer  Pulmonary,emphysema,bronchitis  Arthritis  \
# 49938           0.0           0.0                             0.0        0.0
# 49939           0.0           0.0                             0.0        0.0
# 49940           0.0           0.0                             0.0        0.0
# 49941           0.0           0.0                             0.0        0.0
# 49942           0.0           0.0                             0.0        0.0
# ...             ...           ...                             ...        ...
# 303774          0.0           0.0                             0.0        0.0
# 303775          0.0           0.0                             0.0        0.0
# 303776          0.0           0.0                             0.0        0.0
# 303777          0.0           0.0                             0.0        1.0
# 303778          0.0           0.0                             0.0        0.0
#
#         Depression  Kidney Disease  Diabetes
# 49938          1.0             0.0       0.0
# 49939          0.0             0.0       0.0
# 49940          0.0             0.0       0.0
# 49941          0.0             0.0       0.0
# 49942          0.0             0.0       0.0
# ...            ...             ...       ...
# 303774         1.0             0.0       0.0
# 303775         0.0             0.0       0.0
# 303776         0.0             0.0       0.0
# 303777         0.0             0.0       0.0
# 303778         0.0             0.0       0.0
#
# [33747 rows x 12 columns]

# %%
#add up all the chronic illnesses for each patient
chronic_df['chronic'] = chronic_df.sum(axis=1)

# %%
clean_df['chronic_index'] = chronic_df['chronic']

# %%
clean_df.groupby('chronic_index')['Num of Sick Days'].mean().plot(kind='line', figsize=(15,8))

# %% [markdown]
# ## 5. Create a graphic that compares the percentage of people labeled as 'sick' in each state.

# %%
# code to calculate averages per state

clean_df['sick'] = clean_df['chronic_index'].apply(lambda x: 1 if x in range(1,11) else x)

# %%
clean_df['sick'].value_counts()
# Out:
# 1.0    19891
# 0.0    13856
# Name: sick, dtype: int64

# %%
len(clean_df)
# Out:
# 33747

# %%
state_series = pd.DataFrame(clean_df['state']).reset_index().drop(columns='index')
sick_series = pd.DataFrame(clean_df['sick']).reset_index().drop(columns='index')
state_sick = pd.concat([state_series, sick_series], axis=1)

# %%
state_sick_reset = state_sick.groupby('state')['sick'].sum().reset_index()

# %%
state_sick_reset['percentage sick'] = state_sick_reset['sick'].apply(lambda x: x/len(clean_df) * 100)

# %%
state_sick_reset['percentage sick'] = state_sick_reset['sick'].apply(lambda x: x/len(clean_df) * 100)

# %%
x = state_sick_reset['state']
x = np.array(x)

# %%
y = state_sick_reset['percentage sick']
y = np.array(y)

# %%
data=pd.DataFrame(x,y,)
data
# Out:
#                      0
# 18.807598  Connecticut
# 20.467004   New Jersey
# 19.666933     New York

# %%
state_sick_reset
# Out:
#          state    sick  percentage sick
# 0  Connecticut  6347.0        18.807598
# 1   New Jersey  6907.0        20.467004
# 2     New York  6637.0        19.666933

# %%
# create graphic to compare chronically sick by state
fig , ax = plt.subplots()

ax = plt.bar(x,y)
plt.ylabel('Percentage of Sixck People')
# Out:
# Text(0, 0.5, 'Percentage of Sixck People')

# %% [markdown]
# ## 6. Independent Variables (categorical)
#
# Let's take the column `SMOKDAY2` and start to prepare it so that we can see how it is possibly correlated to `PHYSHLTH`.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Generate a graphic that compares the physical health of the different groups of 'smokers'.

# %% [markdown]
# ## 7. Independent Variables (continuous):
#
# Now let's look at a continuous variable (ALCDAY5) and see how that might impact a person's health.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Calculate the correlation coefficient between `PHYSHLTH` and `ALCDAY5`.
# 5. Generate a graphic that shows the possible relationship between `PHYSHLTH` and `ALCDAY5`.

# %% [markdown]
# ## 8. Additional variables: Choose two additional survey items you would like to investigate do steps  6 or 7 for those variables.

# %%
# your code here

# %% [markdown]
# ## 9. Based on your initial data exploration, what are some hypotheses of what affects a person's health that you would like to further investigate?

# %% [markdown]
# Type out your initial hyptotheses below:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ## Bonus: Create some cool graphics.
