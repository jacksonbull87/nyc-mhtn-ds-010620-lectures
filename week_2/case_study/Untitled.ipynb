# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('case_study.csv', index_col = 0 )
# Out:
# /Users/flatironschool/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (171) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939      9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940      9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941      9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942      9.0     5.0  7182017       7    18   2017    1200.0  2017000005
# ...        ...     ...      ...     ...   ...    ...       ...         ...
# 303774    36.0     5.0  5152017       5    15   2017    1200.0  2017012245
# 303775    36.0     6.0  6252017       6    25   2017    1200.0  2017012246
# 303776    36.0     7.0  7212017       7    21   2017    1200.0  2017012247
# 303777    36.0     7.0  7202017       7    20   2017    1200.0  2017012248
# 303778    36.0     7.0  7252017       7    25   2017    1200.0  2017012249
#
#                 _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938   2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939   2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940   2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941   2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942   2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
# ...              ...       ...  ...       ...       ...       ...      ...
# 303774  2.017012e+09       NaN  ...       3.0       2.0       2.0      4.0
# 303775  2.017012e+09       NaN  ...       2.0       2.0       2.0      4.0
# 303776  2.017012e+09       NaN  ...       2.0       2.0       2.0      4.0
# 303777  2.017012e+09       NaN  ...       9.0       9.0       9.0      9.0
# 303778  2.017012e+09       NaN  ...       3.0       2.0       2.0      4.0
#
#         _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# 49938        2.0       1.0       1.0       NaN       NaN       1.0
# 49939        1.0       2.0       2.0       NaN       NaN       2.0
# 49940        2.0       1.0       1.0       NaN       NaN       2.0
# 49941        2.0       1.0       1.0       NaN       NaN       1.0
# 49942        1.0       1.0       1.0       NaN       NaN       2.0
# ...          ...       ...       ...       ...       ...       ...
# 303774       2.0       1.0       1.0       NaN       NaN       1.0
# 303775       2.0       1.0       1.0       NaN       NaN       1.0
# 303776       2.0       1.0       1.0       NaN       NaN       1.0
# 303777       9.0       9.0       9.0       9.0       9.0       9.0
# 303778       2.0       1.0       1.0       NaN       NaN       1.0
#
# [34545 rows x 358 columns]

# %%
df.isnull()
# Out:
#         _STATE  FMONTH  IDATE  IMONTH   IDAY  IYEAR  DISPCODE  SEQNO   _PSU  \
# 49938    False   False  False   False  False  False     False  False  False
# 49939    False   False  False   False  False  False     False  False  False
# 49940    False   False  False   False  False  False     False  False  False
# 49941    False   False  False   False  False  False     False  False  False
# 49942    False   False  False   False  False  False     False  False  False
# ...        ...     ...    ...     ...    ...    ...       ...    ...    ...
# 303774   False   False  False   False  False  False     False  False  False
# 303775   False   False  False   False  False  False     False  False  False
# 303776   False   False  False   False  False  False     False  False  False
# 303777   False   False  False   False  False  False     False  False  False
# 303778   False   False  False   False  False  False     False  False  False
#
#         CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  _PASTAE1  \
# 49938       True  ...     False     False     False    False     False
# 49939       True  ...     False     False     False    False     False
# 49940       True  ...     False     False     False    False     False
# 49941       True  ...     False     False     False    False     False
# 49942       True  ...     False     False     False    False     False
# ...          ...  ...       ...       ...       ...      ...       ...
# 303774      True  ...     False     False     False    False     False
# 303775      True  ...     False     False     False    False     False
# 303776      True  ...     False     False     False    False     False
# 303777      True  ...     False     False     False    False     False
# 303778      True  ...     False     False     False    False     False
#
#         _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# 49938      False     False      True      True     False
# 49939      False     False      True      True     False
# 49940      False     False      True      True     False
# 49941      False     False      True      True     False
# 49942      False     False      True      True     False
# ...          ...       ...       ...       ...       ...
# 303774     False     False      True      True     False
# 303775     False     False      True      True     False
# 303776     False     False      True      True     False
# 303777     False     False     False     False     False
# 303778     False     False      True      True     False
#
# [34545 rows x 358 columns]

# %%
for col in df:
    print(col,':', col.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e4a35b9d3c04> in <module>
#       1 for col in df:
# ----> 2     print(col,':', col.isna().sum())
#
# AttributeError: 'str' object has no attribute 'isna'

# %%
# def create_list_columns_to_drop():
list_of_dropped_columns = []
for col in df.columns:
    if df[col].isna().sum() == len(df):
        list_of_dropped_columns.append(col)

# %%
list_of_dropped_columns
# Out:
# ['COPDCOGH',
#  'COPDFLEM',
#  'COPDBRTH',
#  'COPDBTST',
#  'COPDSMOK',
#  'HAREHAB1',
#  'STREHAB1',
#  'CVDASPRN',
#  'ASPUNSAF',
#  'RLIVPAIN',
#  'RDUCHART',
#  'RDUCSTRK',
#  'BPEATHBT',
#  'BPSALT',
#  'BPALCHOL',
#  'BPEXER',
#  'BPEATADV',
#  'BPSLTADV',
#  'BPALCADV',
#  'BPEXRADV',
#  'BPMEDADV',
#  'BPHI2MR',
#  'ARTTODAY',
#  'ARTHWGT',
#  'ARTHEXER',
#  'ARTHEDU',
#  'ASTHMAGE',
#  'ASATTACK',
#  'ASERVIST',
#  'ASDRVIST',
#  'ASRCHKUP',
#  'ASACTLIM',
#  'ASYMPTOM',
#  'ASNOSLEP',
#  'ASTHMED3',
#  'ASINHALR',
#  'PAINACT2',
#  'QLMENTL2',
#  'QLSTRES2',
#  'QLHLTH2',
#  'SLEPTIM1',
#  'ADSLEEP',
#  'SLEPDAY1',
#  'SLEPSNO2',
#  'SLEPBRTH',
#  'CNCRDIFF',
#  'CNCRAGE',
#  'CNCRTYP1',
#  'CSRVTRT2',
#  'CSRVDOC1',
#  'CSRVSUM',
#  'CSRVRTRN',
#  'CSRVINST',
#  'CSRVINSR',
#  'CSRVDEIN',
#  'CSRVCLIN',
#  'CSRVPAIN',
#  'CSRVCTL1',
#  'SSBSUGR2',
#  'SSBFRUT3',
#  'WTCHSALT',
#  'DRADVISE',
#  'MARIJANA',
#  'USEMRJN1',
#  'RSNMRJNA',
#  'IMFVPLAC',
#  'HPVADVC2',
#  'HPVADSHT',
#  'TETANUS',
#  'LCSFIRST',
#  'LCSLAST',
#  'LCSNUMCG',
#  'LCSCTSCN',
#  'CAREGIV1',
#  'CRGVREL2',
#  'CRGVLNG1',
#  'CRGVHRS1',
#  'CRGVPRB2',
#  'CRGVPERS',
#  'CRGVHOUS',
#  'CRGVMST2',
#  'CRGVEXPT',
#  'CIMEMLOS',
#  'CDHOUSE',
#  'CDASSIST',
#  'CDHELP',
#  'CDSOCIAL',
#  'CDDISCUS',
#  'EMTSUPRT',
#  'LSATISFY',
#  'SDHBILLS',
#  'SDHMOVE',
#  'HOWSAFE1',
#  'SDHFOOD',
#  'SDHMEALS',
#  'SDHMONEY',
#  'SDHSTRES',
#  'FIREARM4',
#  'GUNLOAD',
#  'LOADULK2']
