# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# For this lab you will analyze the yelp data for a group of businesses to learn more about an industry. You will choose a type of business (Italian Restuarants, Nail Salons, Crossfit gyms) and a location to analyze. Then you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer questions about the data.
#
#
# ### Process:
#
# 1. Read through the SQL questions and the API documentation to determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create code to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
#
# ## SQL Questions:
#
# - Which are the 5 most reviewed businesses?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - Return the text of the reviews for the most reviewed restaurant.
# - Return the name of the business with the most recent review.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# Lok at the question and determine what data you will need to store in your database in order to answer the questions. Start to thin about your DB schema. What tables will you want to create and what columns will you ahve for those tables.
#
# Look at the API documentation, and determine what fields of the API response you will match up with the columns you want in your DB tables.
#
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ## Part 2 - Set up the DB
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %% [markdown]
# ### Foriegn Keys
#
# For this project you will have two tables that you need to link using a foreign key. Below is some information about how to create a foriegn key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/

# %% [markdown]
# ### Using DB:
#
# For this lab, you can either store the data on one DB or put in on both of the partners DBs. If you decide to put it on one DB, you want to make sure both partners have access to it.  To do this you want to add a user to your DB.
#
# [how to add a new user](https://howchoo.com/g/mtm3zdq2nzv/how-to-add-a-mysql-user-and-grant-privileges)

# %%
## Connect to DB server on AWS
import config
import mysql.connector
cnx = mysql.connector.connect(
                            host=config.mycred['host'],
                            user=config.mycred['user'],
                            password=config.mycred['password'],
                            port=config.mycred['port'],
                            database='Yelp_Business'

)

cursor = cnx.cursor()

# %%
#adding test commit

# %%
## Create new DB 

cursor.execute('''CREATE DATABASE Yelp_Business;
''')

# %%
# Create a table for the Businesses

# Create a table for the Businesses

#Columns: Name (string), Location(string), Review_Count (INT), Rating (FLoat), Price(String), Business_ID(string) (Primary Key)

cursor.execute('''CREATE TABLE Businesses (
                                Name varchar(255),
                                Location varchar(255),
                                Review_Count int,
                                Rating float,
                                Price varchar(255),
                                Business_ID varchar(255) NOT NULL,
                                PRIMARY KEY (Business_ID)
)

;

'''

)

# %%
# Create a table for the reviews

# Create a table for the reviews

#columns: Business ID(Foreign Key), Review Text(string), Review Date(String), Review ID (string)

cursor.execute('''CREATE TABLE Business_Reviews (
                                Review_Text varchar(255),
                                Review_Date varchar(255),
                                Review_ID varchar(255),
                                Business_ID varchar(255) NOT NULL,
                                FOREIGN KEY (Business_ID)
                                    REFERENCES Businesses (Business_ID))

;

'''

)

# %% [markdown]
# ## Part 3 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %%
# Write a function to make a call to the yelp API

import requests

url = 'https://api.yelp.com/v3/businesses/search'
api_key = 'Gh_Hoaof6K6gvy1HxSSBhy4Y0wwwFvIPKgC00UWhvCvkeVhJStATKWD-eMbwilkXhjcdDiqCI3ZBYxfq0nV6CvpGhz4T9VPCFgLDH2B54eqTff1-a7PQd9fR7kHpXXYx'

headers = {'Authorization': 'Bearer {}'.format(api_key),
    
    
}
 
term = 'chinese restaurant'

location = 'New York City'

limit = 50

offset = 50

url_params = {'term': 'chinese restaurant'.replace(' ', '+'),
              'location': 'New York City'.replace(' ', '+'),
              'limit': 50,
              'offset': 50
    
}

def call_yelp_data(url,headers, url_params):
    response = requests.get(url, headers=headers, params=url_params )
    data = response.json()
    business_data = data['businesses']
    return business_data

# %%
#returns a list of business dictionaries
business_data = call_yelp_data(url,headers, url_params)
# Out:
# {'businesses': [{'id': 'Xf6e3HaP0AgMBxY7dEDkOA', 'alias': '99-favor-taste-new-york-12', 'name': '99 Favor Taste', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3WBk8VLxBAWeXOSqvYoXgw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/99-favor-taste-new-york-12?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 1817, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'hotpot', 'title': 'Hot Pot'}, {'alias': 'bbq', 'title': 'Barbeque'}], 'rating': 4.0, 'coordinates': {'latitude': 40.7176199, 'longitude': -73.99249}, 'transactions': ['restaurant_reservation'], 'price': '$$', 'location': {'address1': '285 Grand St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10002', 'country': 'US', 'state': 'NY', 'display_address': ['285 Grand St', 'New York, NY 10002']}, 'phone': '+16466829162', 'display_phone': '(646) 682-9162', 'distance': 1348.6324758108813}, {'id': 'Q1TpfbuPwKPFrNFyu-u2_g', 'alias': 'han-dynasty-brooklyn-2', 'name': 'Han Dynasty', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxbMumdu8Q1e3iCxJ2qZfQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/han-dynasty-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 260, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.0, 'coordinates': {'latitude': 40.6911319610036, 'longitude': -73.9825977757573}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1 Dekalb Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11201', 'country': 'US', 'state': 'NY', 'display_address': ['1 Dekalb Ave', 'Brooklyn, NY 11201']}, 'phone': '+17188580588', 'display_phone': '(718) 858-0588', 'distance': 1872.1778710541835}, {'id': 'ynB8T3htx8s5V0YV8gVPGA', 'alias': '21-shanghai-house-new-york-4', 'name': '21 Shanghai House', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JTTk7-6DC-xGzthdKRK4CA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/21-shanghai-house-new-york-4?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 428, 'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}, {'alias': 'dimsum', 'title': 'Dim Sum'}], 'rating': 4.0, 'coordinates': {'latitude': 40.7140138244835, 'longitude': -73.9964454932541}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '21 Division St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10002', 'country': 'US', 'state': 'NY', 'display_address': ['21 Division St', 'New York, NY 10002']}, 'phone': '+12122268998', 'display_phone': '(212) 226-8998', 'distance': 969.9399795414205}, {'id': 'ikx8R8u2lmxhpLGByCjgPw', 'alias': 'house-special-甘來飯店-new-york', 'name': 'House Special 甘來飯店', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PO0lvtD9QTXh1Bt0j-S9mA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/house-special-%E7%94%98%E4%BE%86%E9%A3%AF%E5%BA%97-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 53, 'categories': [{'alias': 'cantonese', 'title': 'Cantonese'}], 'rating': 4.0, 'coordinates': {'latitude': 40.71785, 'longitude': -73.9967999}, 'transactions': [], 'location': {'address1': '171 Hester St', 'address2': '', 'address3': None, 'city': 'New York', 'zip_code': '10013', 'country': 'US', 'state': 'NY', 'display_address': ['171 Hester St', 'New York, NY 10013']}, 'phone': '+12123439496', 'display_phone': '(212) 343-9496', 'distance': 1399.7906969149235}, {'id': 'sQw7aEos_0FmO0UFtrJokg', 'alias': 'clay-pot-west-village-new-york-2', 'name': 'Clay Pot - West Village', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SB ...

# %%
# Write a function to take your parsed data and insert it into the DB
# write a function to parse the API response 
# so that you can easily insert the data in to the DB

# write a function to parse the API response 
# so that you can easily insert the data in to the DB

def parse_data(business_data):
    business_tuple_list = []
    for business in business_data:
        business_rev = business.get('price', 'No Price Listed')
        business_tuple = (business['name'],
                            business['location']['city'],
                            business['review_count'],
                            business['rating'],
                            business_rev,
                            business['id'])

        business_tuple_list.append(business_tuple)
    return business_tuple_list

# %%
#function to insert business into database

#create an insert statement

insert_statement = ('''INSERT INTO Businesses (Name, Location, Review_Count, Rating, Price, Business_ID)
                        VALUES (%s, %s, %s, %s, %s, %s);
'''
)


def db_insert(cnx, cursor, parsed_results):
    cursor.executemany(insert_statement, parsed_results)
    cnx.commit()

# %% [markdown]
# ## Part 4 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews.

# %%
# write a SQL query to pull back all of the business ids 
# you will need these ids to pull back the reviews for each restaurant

cursor.execute('''SELECT Business_ID FROM Businesses;
''')

# %%
results = cursor.fetchall()

# %%
# results

# %%
# create a list of business ids
    
list_of_business_ids = [item[0] for item in results]

# %%
review_url = 'https://api.yelp.com/v3/businesses/{id}/reviews'

# %%
#function to get reviews for one business ID which returns one dictionary of reviews
def one_business_review_call(business_id):
    url = f'https://api.yelp.com/v3/businesses/{business_id}/reviews'
    response = requests.get(url, headers=headers)
    if not response.ok:
        print(f"Response failed for {business_id}")
        print("response.text:", response.text)
        return list()
    data = response.json()
    return data['reviews']

# %%
#parse one business review set into a tuple. this returns one review tuple
def parse_business_review(review, biz_id):
    review_tuple = (review['text'],
                    review['time_created'],
                    review['id'],
                    biz_id)
    return review_tuple

# %%
#create an insert statement to insert review tuple into database
review_insert_statement = ('''INSERT INTO Yelp_Business.Business_Reviews (Review_Text,
                                Review_Date,
                                Review_ID,
                                Business_ID)
                                
                                VALUES (%s, %s, %s, %s);
'''
)

# %%
#create function to insert reviews for a business

def db_insert(cnx, cursor, review_tuple):
    # your code to insert and commit the results
    cursor.execute(review_insert_statement, review_tuple)
    cnx.commit()

# %%
#call, parse, and insert tuples for each business ID

def call_parse_insert(cnx,cursor, list_of_business_ids):
    for biz_id in list_of_business_ids[212:]:
        print(f"fetching and inserting business {biz_id}")
        business_reviews = one_business_review_call(biz_id)
        for review in business_reviews:
            review_tuple = parse_business_review(review, biz_id)
            db_insert(cnx, cursor, review_tuple)

# %%
# call_parse_insert(cnx,cursor, list_of_business_ids)
# Out:
# fetching and inserting business b03GEE_pYlLCdD6yShZKqw
# fetching and inserting business B0e6kXT0doU-n6EvMVGzQQ
# fetching and inserting business B3_K2kUVbYOU0VaLcj_LTw
# fetching and inserting business B3i4zs5wquFu1UZyzYJ-bQ
# fetching and inserting business B7bxdtvLYR7Nmex4AIFd4w
# fetching and inserting business B87c3bE_u53yNYO1cmHSIw
# fetching and inserting business B9_TgZa8rgW5oZOtXZUMCw
# fetching and inserting business B9JGlCZ6XkKPXXhTaYwAlA
# fetching and inserting business B9Mbi12NpBJkZcRtQNtMBA
# fetching and inserting business BAKjtydOJj6KrsGCo-6DEQ
# fetching and inserting business bAMTBEztHz4zQqYiIyzf4w
# fetching and inserting business Bb0h5Rs8ugSM2CjulRhfBw
# fetching and inserting business BbODF2tZuw4xW_RFwMzwRg
# fetching and inserting business BcOuqkUniZJG5NLpdzeOYQ
# fetching and inserting business Bdneg2FELG-GNQnc-zq1YA
# fetching and inserting business bDsXyYwzk4I9_7l51D_gaA
# fetching and inserting business be7zagjfrCYN9EQ5ijld5w
# fetching and inserting business BEuZGvNlbM4tXq7YICyM6w
# fetching and inserting business BF6pY829iPBERt15CG1g3w
# fetching and inserting business bfg1MmcnH6DO1dgF_tLxkA
# fetching and inserting business BG0F1eTMikmXnL2C03Oq3A
# fetching and inserting business bgnM6uy66zupYzb4QdL3vA
# fetching and inserting business bGOZTD9O00OkVA1Pkt3OuQ
# fetching and inserting business bHGETjP_InKy0sIVHFgHyw
# fetching and inserting business BJi6fX-mObaJ3N75v6mwaQ
# fetching and inserting business BJn68qCExYQrPCT7CeOpzw
# fetching and inserting business bK-Y2zCIMolqRDHsaYUCWA
# fetching and inserting business BKABojUN3G9vUrG3AlDZgQ
# fetching and inserting business BKMCAYb9EAivUm3p-vrC9w
# fetching and inserting business BkXb82Y2OIsQ5RpNNQOYmQ
# fetching and inserting business bKXnm2k44mSdU0fP69lY-g
# fetching and inserting business BLYomPDQX5HkNWFJ2Lxfpg
# fetching and inserting business bnDfFdiCcPzhuNWUJORvLQ
# fetching and inserting business BOz0qTUMtAfljd3Vn1rerQ
# fetching and inserting business bpeeh-kkay0ZE7mGXsCVKQ
# fetching and inserting business BPErPpKSNluwcjbKRgze3w
# fetching and inserting business BprO0tybje6_T6HdT6icyQ
# fetching and inserting business BPZfuPvSxCfoppU4lPFm0Q
# fetching and inserting business bRLiKxdNdrA0KHh5_8AYfg
# fetching and inserting business bSi2f2TaOr4RVTI5eFt0wQ
# fetching and inserting business bT4CDzyhV-frXV6ijvXnvw
# fetching and inserting business BtsXojrMtfLRhhFK7rm35A
# fetching and inserting business BtVnZmPY51ZWGY63-mzJ7A
# fetching and inserting business BTWWgZrMo_pS_BK-TYO92g
# fetching and inserting business bVkjBJlAIwKAj9Aw1KVWjA
# fetching and inserting business Bwj7nzWphGV6FaZ_ygTSOg
# fetching and inserting business bZQryeTD6hIsT6lSUxzSSw
# fetching and inserting business bzr6GEQyjpgbkhHAsYaljQ
# fetching and inserting business c_Zpnnae22V6MnMtYhtl0Q
# fetching and inserting business C0uaRMiXCCtjXdQSZhaU_A
# fetching and inserting business c1HgKFOT4Cc7TqWQD5mQBQ
# fetching and inserting business C2o3Iw-DXjoUJFgQIbiqkQ
# fetching and inserting business C3spvfEd8JQJie-yixRgpQ
# fetching and inserting business C3tP0fNNAoxOAC3O406CXQ
# fetching and inserting business c6fkE7yNbpl1akgpEjmtkQ
# fetching and inserting business C6NvtFvXo86_kEWi3qBYWQ
# fetching and inserting business C7e6WIM4CFa4EkzxHWHBRA
# fetching and inserting business CaizM2WaGPX5eRLDOJaqIw
# fetching and inserting business cdoYC58vXUvaTkp3Cl-wnQ
# fetching and inserting business CesS-E8Q3ztX6VnkXO6wBg
# fetching and inserting business CgMgIB_XO4YXJp_MNtB-2g
# fetching and inserting business cGSLzPA_SCWrN3cyT86Nhw
# fetching and inserting business CgsvKB65PZrZV8AhnD-wnw
# fetching and inserting business CHW9sTtJxM6z8cqEy84aWg
# fetching and inserting business cIYsxVEKD9R2X8PD_iivnw
# fetching and inserting business cL8TLMCbs2B-vgy3SFtPGg
# fetching and inserting business CMm3Xf-9v3QJ4ge20MoEVg
# fetching and inserting business cOtB9fWWLrbaBebZDjJquQ
# fetching and inserting business CqQ2Og9kf-LhlUWtODalCQ
# fetching and inserting business cQRQXI3-B5eGFCi_aj1IyQ
# fetching and inserting business CqvbXj6siqnBKaTjqNWwuw
# fetching and inserting business croh2zWlbPyCQTNS11klcg
# fetching and inserting business cWPdP8_GqEWxZKRiOonfDg
# fetching and inserting business cXN55ooqvyJBVbKhM3_tMA
# fetching and inserting business czQm6Ull9V6b-64amhUMyA
# fetching and inserting business d_TC6Om2EBTzHVm_lCgNtg
# fetching and inserting business D13m2P0qKQUWNqIW-lpHZg
# fetching and inserting business d1pRHsBuYCZ4hdk0dyjE-g
# fetching and inserting business d6i6sGHtPmyUkHze5S1lIQ
# fetching and inserting business d6pcRMV1YUDFTKO_p9d-sA
# fetching and inserting business D6ZEcG1FCZ18nekMWrhgMg
# fetching and inserting business d8qCvlsG3jwxQPZc_OGogQ
# fetching and inserting business d96eV2MmIFi4zNNOxBdIZQ
# fetching and inserting business dDXtga5Kgo5B1twdezcZJA
# fetching and inserting business DGrFKsyAOotGDJw-JyXsTw
# fetching and inserting business DH6vM_NdIN5q-xfiHnJ3mA
# fetching and inserting business diCW3Pj1PTVRSyol_d7cZw
# fetching and inserting business DjLxykRuP8OFtGtPPZpfdQ
# fetching and inserting business DKGUSLiqNchBNatKoPM9QQ
# fetching and inserting business DNSFvZtdsqkaidmFSpm-Jw
# fetching and inserting business do4L5yWrrGPPZqVRZDcO2w
# fetching and inserting business DOa_Hm5HHT99GOvlhbydaQ
# fetching and inserting business dpCSDy9uefOEcY44FHss2Q
# fetching and inserting business DpfE0gPBXj-aj2pnEh4E2Q
# fetching and inserting business dpHvmIdKXUeZT1rljtZU6Q
# fetching and inserting business Dqp5Itsj9dN0Ewz8Gm853g
# fetching and inserting business Dqu-5RxNbbpBsL1Ssht9Ng
# fetching and inserting business Dr_eezrA2Cc_azMYnwhRkA
# fetching and inserting business dRKdRpPEo6rJ2X0RYbfZzQ
# fetching and inserting business dtk1Cstz5MHr-B1AOM_nXA
# fetching and inserting business dTZ-q8CwEDo9iVKM0tydnQ
# fetching and inserting business dUfTg2SJ2nH48J8VhAuZ_A
# fetching and inserting business duVKdeFRXc6Tr2UY5vTPwQ
# fetching and inserting business dv-RaOwKFizDe4c5-sVJ5w
# fetching and inserting business dVR5KHPMZoU9rQvxhY5Otw
# fetching and inserting business e03tT0hH6qU-_dR8pwFa0Q
# fetching and inserting business E1fFQqXuO2Ido9hGDmTbDg
# fetching and inserting business E1QQuFMX7DAEt8jV4attkA
# fetching and inserting business e5wK3I_THzF4Ce_OgoSCQw
# fetching and inserting business eAlXJKxQ1zgYNB0LyHHlmw
# fetching and inserting business EAqXEChadTFNm2flg_Y6IQ
# fetching and inserting business EbX_9tqAJs4gW51gZpOB7g
# fetching and inserting business Ece_DRuD1yQjRPJBAebRpw
# fetching and inserting business Edkx9frqYknN9ykTEqTVXg
# fetching and inserting business EDLKX7cCxPbmbmo1XG3xJQ
# fetching and inserting business EFihj7vsRRXiF5la-UURyw
# fetching and inserting business eGIY_25KFspf8KefDQMj-Q
# fetching and inserting business eIPiRkf6KCo9A9Ok-Nr_ow
# fetching and inserting business Ej-hrhc8HFWfijN4X5akOg
# fetching and inserting business ELB1RgCv39PBewQx5gmW7Q
# fetching and inserting business EmJ7rfmv2y6lQZxgA8U__g
# fetching and inserting business EN9_LsFpY44Hkzcnu0jfIg
# fetching and inserting business ENfB82aVceC3VcTfq54rxQ
# fetching and inserting business entLjafiBAYOvbJYHRvyrw
# fetching and inserting business ePVlFbTzdVQFWie__kdplg
# fetching and inserting business eQKYZWnBjPUjINAnFmrmbA
# fetching and inserting business eS9mTLlWwu_Ap2ROMQWPxg
# fetching and inserting business EV2grf7NhNHQTmBXfu1-NA
# fetching and inserting business ev6e12vhY_0y4qE1cRhv0A
# fetching and inserting business EvAJBgBdgOt1jx1EufRN7w
# fetching and inserting business eVDV1ALwvre01Xo8v6BCoQ
# fetching and inserting business EvLkJaWEXTZ8QNBrxOhDsA
# fetching and inserting business Ew3d7Vt18c1MH4_X6ogxQQ
# fetching and inserting business Ex_qolTE5syJ8so0NscfGw
# fetching and inserting business EYpS39ad-GfC5l2F7PwZig
# fetching and inserting business ezh0BG1qWKKLJa99gb-XzQ
# fetching and inserting business EZo6MdrZ_EH_MzUl93xkyA
# fetching and inserting business f_OiLWqldSmNy1MAvtWlPQ
# fetching and inserting business f2MA23sMC3WpJA2LgBlGuQ
# fetching and inserting business f7jZvRH-h76F4emzvKytaQ
# fetching and inserting business fa5a7jksUak7yleWLWMigg
# fetching and inserting business fe9aDWC5giHgcuKjqSr_gQ
# fetching and inserting business feY7PgoRjCp2qReaIitRkQ
# fetching and inserting business FFKUWNdzq1ObyGBDDLqckg
# fetching and inserting business FfUc69vNKeTkGqdpnq0giQ
# fetching and inserting business fgEtBjgOFOE8nMEs5Fr3cg
# fetching and inserting business FH978pIP1TLRuPAH-MbWIQ
# fetching and inserting business FizBsTIAJwNrImIG1mPDcg
# fetching and inserting business fkZV2-UOQORpa7nXE5u_rA
# fetching and inserting business Fl2z1edJw3MONc9rERWRMg
# fetching and inserting business fLq5j4fkFmPD6I2tt6dSWQ
# fetching and inserting business FlZ1zdVEKWv7dwqm8Uw8-w
# fetching and inserting business FMwu9h0KUl3mFDuE-WDbcw
# fetching and inserting business fNAIjp3E05b9lCQesnol8g
# fetching and inserting business fRO4Fwe5uRAajMcTwLbVkA
# fetching and inserting business Fv6ueSQwc_ITpXEhybHvtA
# fetching and inserting business fVbUVAiLiGgLA_nxBFxyww
# fetching and inserting business FvsFSGzbmV56gqtYY4ZfQQ
# fetching and inserting business fVsH6QIJPzXpVbgmeiolsA
# fetching and inserting business FXFQJmhK6elesopXdhjvFQ
# fetching and inserting business FXhSEZfIqjMZh4hR0_8jMQ
# fetching and inserting business FYWwW5lcxKzaA98Xgw8bqA
# fetching and inserting business FZpm4_fbd6P984foOUejWg
# fetching and inserting business g_5V15Xp1OvB1QXuGMstYA
# fetching and inserting business g_xU-3gfa3urAyi98LFHPA
# fetching and inserting business g-Ln2hn8-T63T2orCTVbeQ
# fetching and inserting business g0Xj6-LnjP34zVpHTN9V7Q
# fetching and inserting business g42C_GsiLWzbVY2OZQsoyw
# fetching and inserting business g4EXxoV0z_TnyWF8h9xMKQ
# fetching and inserting business g512kssHLLTdDbUJHTmJFw
# fetching and inserting business GCcJqfBm3Fq-ccYwit6xcw
# fetching and inserting business GcHaiid2EZpYBTOoquvhUg
# fetching and inserting business Gd3_3mxOvj2xYiqysV8rbQ
# fetching and inserting business GDqIF-JMOO-8EM3yKn25_w
# fetching and inserting business GDWVTV11eq92ElXD9mstBw
# fetching and inserting business GGRMY-twaqZf_NIAprBJkg
# fetching and inserting business gj3TK9OEeXbb2-3Yp2Laxg
# fetching and inserting business gJXNSJ9VXTuCFmp_Kl9TVQ
# fetching and inserting business GJZnf3B-ADjlCV1NXsHvGQ
# fetching and inserting business gKjp0KHyrU1AFPOnkuo_Fw
# fetching and inserting business GKZa6xX1ZctdDTLDyfGBHw
# fetching and inserting business gl9UKHI6G-JhIBjjLFOhYA
# fetching and inserting business glccbDYpXzsozu7truCf5w
# fetching and inserting business GpCZORguVJZGpd5GoL9Arg
# fetching and inserting business gPId7ENK1ZA1qrNwI4z4UQ
# fetching and inserting business gQ6DNeLNWQV-zwWyuFeBpg
# fetching and inserting business GrxbGiLMkl1jd665k1lbIQ
# fetching and inserting business GVaTZnN7a-DkrK57l7BbGw
# fetching and inserting business gVcQC9fcWFB5kyLjFCsx1w
# fetching and inserting business gXnC_aZR09BvqEQKGKFjBg
# fetching and inserting business GzY2EjCmGNgvRd7IE20fTA
# fetching and inserting business H_KyiRhwho8rdlw_R93_0Q
# fetching and inserting business H1jops1lmuhrq9lP7lEGJQ
# fetching and inserting business h3yz3w8ke1jIaGnqGln93A
# fetching and inserting business h4co9O0SLuvhTtr_Cs9IIQ
# fetching and inserting business H87c1gVVCKneyI0LxaDFxQ
# fetching and inserting business H89jrU17lNnguPaHbmzhAw
# fetching and inserting business hBbAmEYXM4L03AU9Vt_p9g
# fetching and inserting business hdiQrGDT8enOzpxaipBzNA
# fetching and inserting business hdiTkEnD14VpXNl-APTg2g
# fetching and inserting business HDoJIH-qW9FqJ5WB-bKTqA
# fetching and inserting business hDT_KAXQgHpchcwG5_gv0Q
# fetching and inserting business HFEEjAKuCardL5F8DbSo0A
# fetching and inserting business HFF3zb3LVqxqds-7DlFqKQ
# fetching and inserting business hh0W5CPtx2MoyQGb1kAEEA
# fetching and inserting business HJIw5_NDZXLuORi1NGDBOA
# fetching and inserting business hjlvKeRTHA5mh1dNX4yM-w
# fetching and inserting business HKlcHprrOCbwMw6x71zYLg
# fetching and inserting business hNFe8WhCibrqT4sFcZmAgw
# fetching and inserting business hQq78Foj5L062Nwyd_m9BQ
# fetching and inserting business HR_a2QSA_KJZIakufAJUmg
# fetching and inserting business HScFap2SwbUlfC-QXVkxFA
# fetching and inserting business HsMExJ0PYZnFACK_T1iUBg
# fetching and inserting business hUdRX0a_2ZZEmB8KCp-WYw
# fetching and inserting business hUTDWZofpjLrohhJMYeawA
# fetching and inserting business HvN9eVtlm9MnOQCL_GlRSg
# fetching and inserting business hWkbadE0u-Eiqg9SAm176Q
# fetching and inserting business hXqrA_Z3jZ8Q1O6ZehWSwQ
# fetching and inserting business HZWHBfeuP4Fb6y8b8uqnbA
# fetching and inserting business I_Va7AZSHpEwX75S-3hHLQ
# fetching and inserting business i-s1bcKdqQdm6JiVN0JRMA
# fetching and inserting business i2Wukiku_P0sMwov7jY58A
# fetching and inserting business I39S72G5LG9uyDz2cNWJcw
# fetching and inserting business i4cyV13lYIS4mcJKZW75cA
# fetching and inserting business I4FWrwXDC91lsfQLXYSeXA
# fetching and inserting business i6RhqnCJ_oUfTu5LikGXUg
# fetching and inserting business iAlqJJHbbeY2Lb7tPt_CQA
# fetching and inserting business iB1tr_xJk7aAt0AhewoB9Q
# fetching and inserting business iCjntZ9WI6Vl_onP_JqZPA
# fetching and inserting business icZcEK39HXuL2q08i4EkkQ
# fetching and inserting business ieOIBz6Gfqmwm1B0wUzh9g
# fetching and inserting business iFAAI-7NoceHYVybom5SyA
# fetching and inserting business igcUHNvsKc-s-RtvUmkg2w
# fetching and inserting business igFRhlkG_cKF3a87fbVexw
# fetching and inserting business IgTNgGE0qvTjkmCUzrNwtQ
# fetching and inserting business iHiEMvbpLzNYTMsd5-VnQw
# fetching and inserting business IhSVn0TaX8xXb3wcQ-fgcA
# fetching and inserting business iJ5jzto3CFsILOFhd4V4Kg
# fetching and inserting business IjRxYyr41Yl1fGhIrss1vg
# fetching and inserting business ikx8R8u2lmxhpLGByCjgPw
# fetching and inserting business inp9N7bo9zqQSa8h8UBhqg
# fetching and inserting business IoAUbSudW1Mds5_XY_01Rg
# fetching and inserting business IoPJ1I0eQn6wnrFAoqFXOw
# fetching and inserting business ipv4lBvbfVzCnSahqrJckQ
# fetching and inserting business IQ91FltwJmIPhS6fKKf2pw
# fetching and inserting business IqbHVeqgewmbeSMXBhbqSw
# fetching and inserting business iQKKS_QwYcgrjFISuDClqQ
# fetching and inserting business isIFCDLE3VIDJcqhVy_klA
# fetching and inserting business iSjPBJRiWqrgxW7ZM3CGig
# fetching and inserting business ItZ8CzZAGXGjB8_9HxDIXg
# fetching and inserting business j0Q-yyxS2WiL3foCJEV4eg
# fetching and inserting business J6ZCPE3Fu1Ikgy9qO7Cl3Q
# fetching and inserting business j9TdOBSQ1LRw8v3hW5fObQ
# fetching and inserting business J9UA6rzI5WW_cDGjwDnF5g
# fetching and inserting business JAC3_9kPdF0TFVBt3gYQVA
# fetching and inserting business JaKLZrh1Y_2qB_0Gc3bk3A
# fetching and inserting business JbAdL2vOd-8O_Xa2wRktug
# fetching and inserting business jc7lVTvmYMIK5RNpENtS6w
# fetching and inserting business JFFVmuwj8pnSLePgy3f2Iw
# fetching and inserting business jfnDwWBGK4JoWE5jbeKxSw
# fetching and inserting business jfOMJ8y3llPbVJosDybLMw
# fetching and inserting business jjJc_CrkB2HodEinB6cWww
# fetching and inserting business JjzCmRn3q8JrlwHx8nFhAA
# fetching and inserting business JKYycG6LhEQZ-O7JtmS4zA
# fetching and inserting business jLhKLKuNPMTzAMJgEY5DsQ
# fetching and inserting business Jn7Wtek5_R12TKp2VUJuhw
# fetching and inserting business joSU4pnYVMhAuZ6ccaqqdA
# fetching and inserting business Jr8S-deYDqbDoo-eJI7nyg
# fetching and inserting business js65NHXG9khCfoxvw4w4cA
# fetching and inserting business jSUUcyV76hlCBAyHWAOm0w
# fetching and inserting business jVuj54_J9z0w9DjKPoUK2g
# fetching and inserting business jwKPVep2qZYBUA6SLLQPvg
# fetching and inserting business JWQlPP4Oxrtwb0rNjnVgIg
# fetching and inserting business jWuUibgnTGsJibOrr6UUSw
# fetching and inserting business Jy7htqnnxlKB2vZO42_-aw
# fetching and inserting business JzD9nfJWHwnG-2Wk87muHg
# fetching and inserting business K0qsGnFv-edPDqVBdLCocQ
# fetching and inserting business k34VgKhpuIRPEr8vKSMwjA
# fetching and inserting business k4QfaFoqtpEZ1LZylJZqww
# fetching and inserting business k67-o4M_l_7LO_RxWBIpbA
# fetching and inserting business k8GFfCXO2FIIJIo0ICYSRA
# fetching and inserting business k8OPcNle9zJNFf0VhAXR2A
# fetching and inserting business k8vE6g59i4JrAmXd6K1g5w
# fetching and inserting business KavW0SjAiElP2ajaexNQDQ
# fetching and inserting business kbUZnWtro1h8BuPcSOd74g
# fetching and inserting business kBZggrnSP1kcUMnsnfkTaQ
# fetching and inserting business KBZQN540Xz6LbXLRVOMc0w
# fetching and inserting business KEBKGGGkDhnuYdKrjzZblw
# fetching and inserting business kesYSgOJW5krU6L8n9qQ4Q
# fetching and inserting business KfaG5PoTEPpbODHBta9irw
# fetching and inserting business KGD7hsGHd3KpiEGOApZLvQ
# fetching and inserting business kHlYnhMOoMBbe3VCZflpKQ
# fetching and inserting business KJFosOrLotvQo_rntg0sjA
# fetching and inserting business KJTTqIxuB0BEsYxLaYyAZw
# fetching and inserting business KJYG0F-aOAiWjQs4YBygTg
# fetching and inserting business klAhw3xLQi9GF1tf_HnS7w
# fetching and inserting business KMz2FsTC6ttORRtwVazraw
# fetching and inserting business kNOr6_g6QfBHdhf89j3g5w
# fetching and inserting business Kqb7MjTPNkjPMoFRd-rWpw
# fetching and inserting business kr_Wu5m0P-AEghraNqXeTA
# fetching and inserting business KS-DmyDoStti9ZjAWPO53A
# fetching and inserting business KSleHGTG1yL1E7OEFFPoNQ
# fetching and inserting business kwGaeWUVC_MIxMFw0sM-Ww
# fetching and inserting business kWJF8L1u5jdlkLBItUu16w
# fetching and inserting business kwq1W0opBnOYKoUXWYyQ5g
# fetching and inserting business kwqOmEwWJ0D9PyCdFGE3-g
# fetching and inserting business KwTr8s5IrVq6tMO4XE6P-w
# fetching and inserting business kxv4jD_qXRPVrV0oPR7isQ
# fetching and inserting business kxykwx5qTWBhlMh18MQ82Q
# fetching and inserting business kyJ0CtJ2Lrid_YdZWobf7w
# fetching and inserting business l_gQf_4NgPMJcx2OkjsMfg
# fetching and inserting business l-AcQjh1DarxLq3Ur6vOxw
# fetching and inserting business l1nX-f46dmOEmYPoiuLSaw
# fetching and inserting business L2ZW-MdvRJ3gM2RIq8STbA
# fetching and inserting business L37A2JWXfwR_PgKColA8xA
# fetching and inserting business l44CFBTejwL0ElKmkH7xQQ
# fetching and inserting business l5C_XHvTZihVzPKgclRZqg
# fetching and inserting business l6ZFhrONGp0b80bxnOFiwg
# fetching and inserting business l7G5tDA96xbA_bx1ZgkOeg
# fetching and inserting business Lbs8QBRN1U7IYBo5Mcv-RQ
# fetching and inserting business ldEnlFvW6Rqqoryh6hdDpQ
# fetching and inserting business ldRY5AQr0y1xxsZ0UzYAeQ
# fetching and inserting business LevaZe9HJHteg4nSp-pt2g
# fetching and inserting business lFw3pv2MQ588kSfWodSIAQ
# fetching and inserting business lgHmMRBaU-48kGaNz3jYxg
# fetching and inserting business lGLeaVcg7U4tOfJFhVqGng
# fetching and inserting business lgS9lE0Y9FhzT68zCj5QCw
# fetching and inserting business lh5sd985Q1bDxi-xRWBzjw
# fetching and inserting business liGIz8CzhyS1udx1aefjng
# fetching and inserting business liZmIO0FqZwslLJfLDkfgw
# fetching and inserting business LJntAPKObO0OfydYm3_bzQ
# fetching and inserting business LJoNFt19j3wtumQP2J7i8g
# fetching and inserting business lJsNGj70bmuBrcAubvfTAQ
# fetching and inserting business LktxVJKPev11aC5SeqlLTA
# fetching and inserting business lkWcA6W73HDgogF5D104-w
# fetching and inserting business lKxmH-hQ6ezKbq4URKrd-Q
# fetching and inserting business lmiwPS9tl3cyMDGDeVstqQ
# fetching and inserting business LMyvruexOQzzHQrAgbdqiA
# fetching and inserting business LOeDR4X-YRToeo3hy_plew
# fetching and inserting business Lp8vAE5nHSt5zbu-lSGK8A
# fetching and inserting business lpLd3AFaMOV7LfPtvUiq8A
# fetching and inserting business LpVbI-E9C-CSp7WhU5h2Iw
# fetching and inserting business lQ8Fzgji9qmgRXkFcvAsVQ
# fetching and inserting business lQeuBd1k7Q6rtsVY9hTjCw
# fetching and inserting business lRSiXYB09Z5x1iINqQ7rHA
# fetching and inserting business lSrdxUNxyMgh5YU903JUiw
# fetching and inserting business LT0yyLNM84EiJj9DL0rfHA
# fetching and inserting business LXmlfAmrGA3NfvYSfxIVvQ
# fetching and inserting business lxQ-tzFmL1tmUqZUN-CSRQ
# fetching and inserting business lYIZYnnEpjbWu7ZM-SuCkQ
# fetching and inserting business lynQoI3w_pzYfHGeuUU-Qg
# fetching and inserting business LZ2Oq8xbDPc5HDfSk5J6jQ
# fetching and inserting business LztkKM-lvRraBbS9TVXzcg
# fetching and inserting business M-odQWSEfsR2mVEw7nKG-g
# fetching and inserting business m1cJLpDN4B-_0hGgPfe5OA
# fetching and inserting business m2_ZNFos5ugAwe8ft8eaEw
# fetching and inserting business m2Zsy2UAkcDf0cRzk2Yoqw
# fetching and inserting business m6bu1AGIIIM9GNn9_cjsmg
# fetching and inserting business MaZWYgvu08NLQVRcDGGvqQ
# fetching and inserting business MBU4VGyaPKZKhe5x7UMQpA
# fetching and inserting business McU7XI3HoWFELTDaGc1SEw
# fetching and inserting business MD-GiizNpmFbuDIdKGzXnA
# fetching and inserting business mDajKjZjRN4tVGEJFOgF9w
# fetching and inserting business MdDj13LgIs0WdbIdiyqB7Q
# fetching and inserting business MGRo61aHFUeRlWhSbTv2NA
# fetching and inserting business MhceeLrM2_3mcKw5EGLY6A
# fetching and inserting business mhhTORjUdXj-UIDjyGmhBg
# fetching and inserting business MM5P9cKlzovYLcf5qf2SwQ
# fetching and inserting business MmXZLVwWcYugi_TXSHmjeQ
# fetching and inserting business MnjB_RIJG0sDTk7dGggA4w
# fetching and inserting business mOP2_wjgUMqELKDL1Y-U-A
# fetching and inserting business mUl0wtO7tPkBocuJqZ-7Dw
# fetching and inserting business MXstrG3HjF83LcxAd8OpTw
# fetching and inserting business MXYtu8-0eNkW6L4firJfcw
# fetching and inserting business MyFqNpQKY4JtQ-gXSeJxUA
# fetching and inserting business MYPes7EWP5aLiVG1Z_9eFQ
# fetching and inserting business MzA6gitJKqfW4VrdS7AiQw
# fetching and inserting business Mzt7J53rOihwxIt41SH7vg
# fetching and inserting business nAcVK-Y1_ojsRF_04o-x-A
# fetching and inserting business NebgteFykeM1gwiVgPcCHw
# fetching and inserting business neQM053ovAOrf1sVSAPI9w
# fetching and inserting business nFoosLWJGMBL5CRmrGUKyg
# fetching and inserting business nFqb7D7nng2FKunqlSd6XA
# fetching and inserting business Nh7lqzBskdE42FMzSTMJAw
# fetching and inserting business nhez4xxvwwYIQEN2Vrj9mQ
# fetching and inserting business nI1UYDCYUTt23TpGxqnLKg
# fetching and inserting business NiFmuqLM-apdMX_jBPVIgw
# fetching and inserting business NjBgTtcJgdXKLvqYt3C8CQ
# fetching and inserting business nJh1ioLcN6XBQEstR6x9yw
# fetching and inserting business NmJ2xtfZrscfWB_a5wEbXQ
# fetching and inserting business NMX7QiEh1-ZhAY52t9-Iow
# fetching and inserting business NN3mOWF5e_pnR1ArqM2bHQ
# fetching and inserting business np7wKWwTAhetwpXqsWpFkQ
# fetching and inserting business npiIhpcWePbVT3JYEcy3zg
# fetching and inserting business nrPfcOC4mGnEL-9CpoGhMg
# fetching and inserting business Nt3Y26a6OMtdBe8xMMJjqQ
# fetching and inserting business nXh79laNQ7leN92F5Ore-Q
# fetching and inserting business nxTEuWKzkK1tCF4LrhFSUQ
# fetching and inserting business NXZFu7KHBrG02gzYneY5Xg
# fetching and inserting business NZ0zBJ60QNrol6nUeAnLgw
# fetching and inserting business nZI6Ny1MIwjgSJGU_UYKYg
# fetching and inserting business nznIq087BJUN1fLtPQ0Xww
# fetching and inserting business NzU2hb0z0jGEOOv0-zTLEQ
# fetching and inserting business o4qlz8mbN0jI2gCpFbkBIw
# fetching and inserting business obIX3q93sNKq9VcbbRIfTw
# fetching and inserting business oC1MLewpogrJUYoIeDoGBQ
# fetching and inserting business OckVDH3DV7HtMQuTKvNouA
# fetching and inserting business OCTiJwvjoK81WoDwsTkFvA
# fetching and inserting business oD0mN9vXuc1gFRyw1CG-Pw
# fetching and inserting business oe8GEFE4QLFAKt87y7zcgA
# fetching and inserting business OFfZUS-nu6NDnsWe1B2bUQ
# fetching and inserting business OfqANzeWRlZrdHQuG7pI0w
# fetching and inserting business ogCC-lJJYnwXDvKGmKZ6Sw
# fetching and inserting business ojbH3wnRu050hRhkmoxRiA
# fetching and inserting business oJjMYhA6z1_BVaQpSdyl8g
# fetching and inserting business oKtDrJA7uaRvbrgBhF4Q5Q
# fetching and inserting business olRNNJCJ2TJvPRmjBiOcGA
# fetching and inserting business OmCJH9XPC_Zc9S7CWe__Xw
# fetching and inserting business omOPvWNdukvWOC0peXPyng
# fetching and inserting business OMu9_FqiziCCHD-SsMBUrQ
# fetching and inserting business oNN202L_XcNM-tuDHlgkfg
# fetching and inserting business ONQRhDuWv0e9R5xOiI7YAA
# fetching and inserting business oO_X1H5Lxo8sNykx6azLVQ
# fetching and inserting business oowNI_aUmGEFa_VW8BFgRg
# fetching and inserting business OQ93Z1tAmdPqK7twEEvISA
# fetching and inserting business orYWYTk6kNK1YODsADk_tg
# fetching and inserting business OSqcNi7EZLAMtuiQjuoiLg
# fetching and inserting business oTkzgr7hzOAdlP99Auj3GQ
# fetching and inserting business OuHB-EdeXmQ26QDzAsDxyw
# fetching and inserting business OUXpyNFn4XY-2cNyURHCQw
# fetching and inserting business OVAV0k2O1kqeuRFyt95qzg
# fetching and inserting business OvdCm3j_5HzItolfvwrEUA
# fetching and inserting business oWBDdSamOzxMJzsD_-seXg
# fetching and inserting business oXkCGBRjP-qERDlEgPlwxQ
# fetching and inserting business OXTcpNk9ZXuOxPnjpcSs7w
# fetching and inserting business OyUqDYNctt81gsNLvfHp5A
# fetching and inserting business oyyubJoK0VZ2V3a5sVJULg
# fetching and inserting business P2bxlKAmRWZIpHdJ_JT3fg
# fetching and inserting business p2sAfaFyfFj9nYPyqcmQdw
# fetching and inserting business p4W_z-zh96LHEAtQ8LRSVQ
# fetching and inserting business pb_cHcy8D8UC-jQ-Q524ug
# fetching and inserting business PBh9J_5HF8dtg2MTTUqVnw
# fetching and inserting business pBNMZp_tKCAfRNx7-ybcHQ
# fetching and inserting business PBUIaPtgnhmdHE3KHglK-g
# fetching and inserting business pCfGgX0WxGASGM4-Yhr2Pw
# fetching and inserting business pepM7-yv4-jCT6S1nl6fPg
# fetching and inserting business Pfjb9Rn5Th7R-pLXVARwlA
# fetching and inserting business PGBHteqfNcTqesQFKqqdsg
# fetching and inserting business PGeL1b4xNJggpZsHEGoxjg
# fetching and inserting business pGYovGGnxm0tMmkiQJPygA
# fetching and inserting business pjbMNd88LRNxvrwaO8kEhQ
# fetching and inserting business PkA0eLD1AZ0voGAmUSG9mg
# fetching and inserting business pl2YasX89E2kzCzTqoO3Bw
# fetching and inserting business pMD9ZQcyKfD6N2zb0kiR2A
# fetching and inserting business pmJqb7-EckluXUk6Rtml6A
# fetching and inserting business pNe8ZCkGTe4cXfKdOF7kYQ
# fetching and inserting business poRWXhCG1-mVxs1kuw_ZEg
# fetching and inserting business PphgRM2pDtbAB6pBsU6r3Q
# fetching and inserting business PPQSf_1JWkbjFHi1S0nSNA
# fetching and inserting business Pr-q47vsmM4aoc2t_Sfk8w
# fetching and inserting business prCmvXTGj30EJexLFOzfjw
# fetching and inserting business pSSajdYNKTyAGV8-fk7fWQ
# fetching and inserting business ptWTdgSzSpH-0LD24QIH-w
# fetching and inserting business PUwrkoUztUYs4VdHlK9qBg
# fetching and inserting business q1A9AGyCpmVhlT7ZkGex-g
# fetching and inserting business Q1TpfbuPwKPFrNFyu-u2_g
# fetching and inserting business q2bIyvU8CQwiB6xe_iVs0g
# fetching and inserting business Q3-zMT4lS0f3m-YK-eh_tw
# fetching and inserting business QaolMEijS7L6eodSneOdng
# fetching and inserting business QbAfrOxbuYKU248SDXHZEQ
# fetching and inserting business QBhHq4eN7rtFzmDUciVL-Q
# fetching and inserting business qbLLdO0VEAWXGnygtQfoDQ
# fetching and inserting business qd5JBbRv6iFBuqaCkCEOvQ
# fetching and inserting business qd9_gxrmskbOT6OLN9sShA
# fetching and inserting business qEe7nIhPfEL6L0-VYhWRrA
# fetching and inserting business qf9ONR0LAAFZ8fLDRkVHww
# fetching and inserting business qFZuYdXy57_ydnsEFdfOxA
# fetching and inserting business qGgQMVExGERqGhZNDM2ROg
# fetching and inserting business qgPYGl1Nuie2XBF1YqJHSA
# fetching and inserting business Qgv2vyUV-DwK8YwrhU-jtw
# fetching and inserting business qH8PVeddtVs9cKN2pwgdkQ
# fetching and inserting business qHi_FA4zSEkFshXQ4Chc9A
# fetching and inserting business qhXIW0LDT4XsoN2IE6dZHg
# fetching and inserting business qiw9Kgsu5YVGrQL_OeDmcQ
# fetching and inserting business QlVBFWxQ-HY-O2AmqHiJxA
# fetching and inserting business Qn-qGoIkj-9uApdxb_VTeA
# fetching and inserting business qNKNl_wfx9MhjImW4KKdrA
# fetching and inserting business QQfwlKFD6X8-ZXf7gfQZqg
# fetching and inserting business qrncvjkiKN5Z-JC06ygy6A
# fetching and inserting business qrydcGQpeDP_1oFvx3qOeg
# fetching and inserting business Qsc2DrX3IR-uGfwnUlOzcA
# fetching and inserting business qU3ejLMndurKQTkM01gutg
# fetching and inserting business qu3niqEXOUdNxCCXnSPBYg
# fetching and inserting business qvXUXFKijyprAOMtxRGyGQ
# fetching and inserting business Qwd4Tv-CqgO2Yl9zZgkKOQ
# fetching and inserting business QY_IgBYFzRulRV8sYUkHZQ
# fetching and inserting business qY1o1MhoRyN84RRhUJtvpQ
# fetching and inserting business qy7CaBk9g519-iZGjrki1g
# fetching and inserting business R0y03SFOY0BdHRUT1LSO0Q
# fetching and inserting business R18bhjYmKxpwfkwGFlWW2g
# fetching and inserting business R26zweQ8-xoZS7iHkXQOvw
# fetching and inserting business r2JVKalbucGf2nryywuL2w
# fetching and inserting business R3UNnA8EbjhNWBHS0wJ0VA
# fetching and inserting business R7EGjHWw0tNheY6-ahH8fQ
# fetching and inserting business R7mKCkD9ZZfeec92GW7esQ
# fetching and inserting business R8V6kbUtyfPAwNNu46vMvg
# fetching and inserting business RBpwDqMpajBLLjMKOPrUxg
# fetching and inserting business rBUTVjRs5CcEMe3dfVRZJQ
# fetching and inserting business rCtsqHtOAOjZ7EUQDFRSbA
# fetching and inserting business rEbwps11tIERRkwQrIXQog
# fetching and inserting business RffIwNrMmEf5auDVP1eURA
# fetching and inserting business RgIFYmjtBp5k90AK1jP7Zw
# fetching and inserting business rGuXwUtNoDp0_GmspjYwcA
# fetching and inserting business rHg81VzTGVREMCfMmgYMog
# fetching and inserting business rJ4N10Nbh-GM49qOSGFoAw
# fetching and inserting business rJeh77RIvtmISisvVoy6TA
# fetching and inserting business rJnd1QVy67DmdKCGxgHjiw
# fetching and inserting business rk8V5c1Wr5gVLKOaY0g4VQ
# fetching and inserting business RkcQl4uEJWblWf4xX8ssqQ
# fetching and inserting business rkeH5HJIuX7ZcOaYNum9xA
# fetching and inserting business RkPakW9XloEm-QB0eNlHmw
# fetching and inserting business rL5F8YnQq9SY0hyece4W2w
# fetching and inserting business RLAs8M-IQfAgp551rkFNGg
# fetching and inserting business rLu0Kbs0fCycSDzeDM2U_g
# fetching and inserting business rN347NNwQ0hDSlbedzI9BQ
# fetching and inserting business rn6SmSqAYx2kLFIAxytMMQ
# fetching and inserting business rnfzNsGTnTuJrVbTYpTgiQ
# fetching and inserting business RoPrfBqmRTqw_cBqcWAfYA
# fetching and inserting business RoqLH-4rDugHlduthnZggg
# fetching and inserting business RoXFN-T1s6moM5smbY_5Gw
# fetching and inserting business Rp-kcJD6Dwaq0c4Kuj6aiw
# fetching and inserting business RPBQC0LGOI1FrXiGKn0jHw
# fetching and inserting business rPKXTHDgtGI4XEo2HuVpow
# fetching and inserting business rPTX2J5KGDkN1QhPD-QOvg
# fetching and inserting business RQRQOO_CGhj16AIz4KqlQA
# fetching and inserting business RrPIJvmje1qb9iaYd6jH0g
# fetching and inserting business rsbjGGa8kh14ZWYSnK5rGQ
# fetching and inserting business RTFIMX31BPeZzx7kJJ1SCA
# fetching and inserting business RUnj4RTVOSbbHE5zyguhrg
# fetching and inserting business RYKGs45OjF-vlb2Ds2Jb_g
# fetching and inserting business RYoc4EBUNOtgbg7c32OG9A
# fetching and inserting business ryvBsB9FrBBZDak87iGS1w
# fetching and inserting business rYw5rQbWRX9buZHZbxqWdA
# fetching and inserting business Rz1eJCYl2AeQ-3ydZrIBxw
# fetching and inserting business S-aX_Pz8F7nDL6kRThKcHw
# fetching and inserting business S0CYlCpjRfq13k2qz06DHw
# fetching and inserting business s25mujxKWphsyFm0Ji1xYA
# fetching and inserting business S2NwTMDe4Vcs6nAoTeMYlA
# fetching and inserting business s5JNxy0eAFgxS2Poi73ODw
# fetching and inserting business S5VN-lFmTdI5VVQ0qFyfCQ
# fetching and inserting business SBJHGtqJyfaU47NPjGAU6A
# fetching and inserting business SBy46BviyBKowPjbTjDsHQ
# fetching and inserting business scTDvJ2M2jDbb1ntVeIyxA
# fetching and inserting business seGYMEYsw6F_H33Md1E1dA
# fetching and inserting business SFleMiroXTeWnXfonRic-w
# fetching and inserting business sfsjk1h50ooC2ioY7m48gw
# fetching and inserting business sgKNAn72O2XMQXS6AWmf9w
# fetching and inserting business sGwQYKPaMJ-tD2E4fQ0EJQ
# fetching and inserting business si4n0EtvAl3QisVHoKPOuw
# fetching and inserting business sinDhwX8Egru_3FCI7bhkw
# fetching and inserting business Sj2StOWkhHIPE6_sS5RMCQ
# fetching and inserting business sjOp9UbbfKbohpEjQt2JRg
# fetching and inserting business sKIYGvENchifk1YwFe77pA
# fetching and inserting business SKoMUaQewpMdj1Mg8QvBNw
# fetching and inserting business skQAnVvpbSpb8zZ1zLDAJA
# fetching and inserting business SMImQM_JfZkIZwflTgOAoQ
# fetching and inserting business SNDUD4LFjVHWwrdAkokxRg
# fetching and inserting business SNhDVaf_n7VDZcfry8mYdA
# fetching and inserting business SoBdWOxymmY5yKANn63UWw
# fetching and inserting business spJTHaNjEzKwoEiYWR1ggA
# fetching and inserting business sQw7aEos_0FmO0UFtrJokg
# fetching and inserting business sR-KTsDa4vafaDak9Ik2sQ
# fetching and inserting business SSDOkx5enfRH3nsniS_2jA
# fetching and inserting business SUHJfh7H2NiQx8c5OWoAyQ
# fetching and inserting business SVJNB9LqI13jtVyKMZVqeg
# fetching and inserting business SXH-A8k7t7C_lmzzVdWQTg
# fetching and inserting business SxKvgnkMMZdhBJcxxKQnww
# fetching and inserting business sxv1oJxG8uu6u4tjKHiJMA
# fetching and inserting business SyvC0s3y0ZrtnLbwnvw7tw
# fetching and inserting business sZ-Y_NgZQOvNS70V1IYjSA
# fetching and inserting business T_72OxeFKvdzX-mKEztHdQ
# fetching and inserting business t_UObgQX6M_ZRn3tk2cXYQ
# fetching and inserting business t1w4qyqyfEdTPhoy-5t3FA
# fetching and inserting business T2fE7hGS83Ba-QNCOqbK4A
# fetching and inserting business t7BIiUN0tFg33kySuuQ0aQ
# fetching and inserting business tA_AoGEL_oGllbU2j77Shw
# fetching and inserting business tDYk6DmmU3buWBs9G0NBXQ
# fetching and inserting business TeBthQZ2xpxyvXheS08ovw
# fetching and inserting business tfMPbnQqJ1P1RIab-o6gtg
# fetching and inserting business tguMh2GgOcU9fu6WN3dqpw
# fetching and inserting business tgvibHhySfASSEqJbScCiQ
# fetching and inserting business TjB0wn5MyHM5rDMBCSCnfw
# fetching and inserting business Tjo8JXQzoBwvw_QYicejiw
# fetching and inserting business TN4RnyqHMSupRFot4Q-_EA
# fetching and inserting business tS4aiWBYgzlqKX898jr3_w
# fetching and inserting business tsHdT1GDibhYYA0JA7Z9tg
# fetching and inserting business tsTGTBrz2TqrYRgdr6vEJQ
# fetching and inserting business TU_BU9HLflYI2xlyqVQdRA
# fetching and inserting business TUpKY3rsYnrYHkbuD46bxg
# fetching and inserting business TV8v5BQXMprtMwhkUXjLdw
# fetching and inserting business TwxP5xU_xyzlf7SVzCnpuA
# fetching and inserting business tXZOJhUUknjTRRo9j4ckZg
# fetching and inserting business tyyqm0ftkoKQxednWNh0Tg
# fetching and inserting business TzhAlljC_843JO7UDDUIaQ
# fetching and inserting business tzqQfzjVhmrhX0DypHOfOw
# fetching and inserting business U0deo-JRQmHrru0uSf6QWA
# fetching and inserting business u0qfikB-ppp6UwoNKqxlRw
# fetching and inserting business U2aUFZARLeSMf4RQIxjuTw
# fetching and inserting business u3YHSsqkj-7Z1moxVWZCsg
# fetching and inserting business u5-S5ElOzXnavuZ2gFsCpg
# fetching and inserting business U5dCWjAxrvLLMH1ErpGfvw
# fetching and inserting business U74_3F7r3tMhd6dmTmDBxQ
# fetching and inserting business uaFHoq-a5XqxF-bsOK9_Qg
# fetching and inserting business ubeG-hyIV8qoSSAk_pAZ2A
# fetching and inserting business ucWrNKS65jUVK6ICUoHC8Q
# fetching and inserting business Ug2_5DOrlfaU1Pce5Lvikw
# fetching and inserting business UiBQ8Uyu4wfOtEM1Rr8ycA
# fetching and inserting business UJtUaOXnwtQA1rb-4BHsCg
# fetching and inserting business ULDVJYTT-47RqbLtlR_FUA
# fetching and inserting business um0U71kITL1NtD4Am6D8Mg
# fetching and inserting business UMsoaYUQUt-anVxe7gi5Vg
# fetching and inserting business UnuTjRj-u7Z8StoFKb-r1A
# fetching and inserting business UNyGz06_7RendbswIyNYtA
# fetching and inserting business unz_YBwCWg-O5id5rxSyDA
# fetching and inserting business uP0zrPN8vCMxTe1jnsKsZQ
# fetching and inserting business uPVYeVOSLmvAkbxM9cTAQg
# fetching and inserting business uthkinOdYCrM0j-5tYC63w
# fetching and inserting business UvQr8V1dD_d6yRsMJi04wA
# fetching and inserting business v0opDMezc6pKgdfR22KUnQ
# fetching and inserting business v2dtG37r1ThqtfEfiFsAUg
# fetching and inserting business v3qL3KqFJYuS_3rCsgpuXQ
# fetching and inserting business V58g7E1AHkuTchTVyLQuYQ
# fetching and inserting business v5CsUc6pr7foHWsoQ0Y36Q
# fetching and inserting business V9cBgn2RFLurwg6lwuLH7w
# fetching and inserting business V9Y5z0NHBDNStB-BX6GUuw
# fetching and inserting business Va_mnsEvBghHXvc7uZIWJQ
# fetching and inserting business vA2VEhW6S1ioX6tXtQdO9A
# fetching and inserting business vAxm4dekBCfaRNoBYbx6OQ
# fetching and inserting business VbFYau70iG_s6UNFwYtGVQ
# fetching and inserting business vbL4Ef8zf4dmdR9Gyl5lkw
# fetching and inserting business VDbMrjBq-XAKZTS_cgB9_A
# fetching and inserting business VDfcGeDs9mUfI0v_QwFHVQ
# fetching and inserting business ves5zPXMxQk1-HK3E1fNhA
# fetching and inserting business vfIg2GGHYIXLx8eR4COc3A
# fetching and inserting business VIur-OanRPkNvbo9rXRlEQ
# fetching and inserting business vkgl6UT8e7PXoVZUhxXq8w
# fetching and inserting business VKVKKCxE9aU6rgfGEkD0_A
# fetching and inserting business VoAuIReq_cPUrFwxbWqG_Q
# fetching and inserting business vPbJRg5umcRMELTDsJik_A
# fetching and inserting business VQ5YGa4L4AT3ugF61hM9qQ
# fetching and inserting business vQe7_ZW_jBSWKtgSiXGIOA
# fetching and inserting business vSkCDRWX6VvP4PJHHFgoDw
# fetching and inserting business VvsZAnEwU4c8Xkyrzx05Nw
# fetching and inserting business VW2Epq3C8jqysu6Edpu-RA
# fetching and inserting business vWEKZVPIYFewfqCOkkvVIQ
# fetching and inserting business vZgJyMZlpSSS_Y-duxd4_A
# fetching and inserting business Vzx-7-jSEBz2g8NuGVhHvQ
# fetching and inserting business W-drUupbzZmbq8QwNG7mDQ
# fetching and inserting business w0pDi_iMZd5MqYQ7t5q1dQ
# fetching and inserting business w3wKbjuNCZnYoPOr-FCk5w
# fetching and inserting business W5RSIwNKBa7k0jeAs5KDYg
# fetching and inserting business Wbmqg0TkOVkzNh3HrJ9DIQ
# fetching and inserting business WCbY8VI2MxsalL2_0i7tkQ
# fetching and inserting business wdGMVLUzocmnl2tST0lheg
# fetching and inserting business wDuf4Qz9qsC62amLZgWNJQ
# fetching and inserting business wfhMIiMh2A2psCGONOVSlg
# fetching and inserting business wGFSTTB6b4MHJJUzBnVJeg
# fetching and inserting business WgQkB7cbPNgj0pLin7gQtw
# fetching and inserting business WgzUkwQkKwraqNzbYDFgWQ
# fetching and inserting business WHXgDm3kcU-aONfjR8tX0A
# fetching and inserting business WIj12zDqIbBucW1hXYhrew
# fetching and inserting business wjIyCBEpCG_HRp8veiI0YQ
# fetching and inserting business WJS06XxRdc6DD1s4LWE9HA
# fetching and inserting business wo7-TKh4B37RTBjPNtkp7w
# fetching and inserting business wobICp6lQP7Y6dfnJ_4Ujw
# fetching and inserting business WpfuHkTsiRN2EerQ8ZaG4g
# fetching and inserting business wpJGWi1LQsCd7Leq3Y4RqQ
# fetching and inserting business wPL0epJzosoFRYox1a5lvA
# fetching and inserting business Wq9cARVEwOmoqfg41mNRNg
# fetching and inserting business wQU3LMmOPNzxL-ptOi_F5w
# fetching and inserting business WRPJeH3goSpj5ke3Pkrnfw
# fetching and inserting business WRRs3smfm6rHP5k4Slzr3w
# fetching and inserting business wSGZA3DOFSUvALZRKCM_Sw
# fetching and inserting business wsMThqit2caUREhOMCOyAQ
# fetching and inserting business WThqnTprg2txsVBt7D0Tkg
# fetching and inserting business wurhcLKXD4YJ5XfTxpbE5Q
# fetching and inserting business WVsPyl-DGRu0O_rQYdIMVQ
# fetching and inserting business wxUTM-FkpCvnoTGJfSXkWg
# fetching and inserting business x_t-FtDa5HVgc-wecp0HBg
# fetching and inserting business X1upzQ1oDfU9Jb378kUkRA
# fetching and inserting business x3_DaW2lWCNovheuZV_nAw
# fetching and inserting business X4hEgOBOLTYFhlWO-gAFxQ
# fetching and inserting business x64xHVZoQj1ZOjzPqVprkw
# fetching and inserting business X8ZS-dgiMIJvhwf9SaDnjw
# fetching and inserting business XaEFFUabnbH8ZF7ccmSAlQ
# fetching and inserting business XBZOes8kvUSoc9Xfu1wrCw
# fetching and inserting business xCHApgtkLpEyh0lz-uhZvg
# fetching and inserting business XcK-u5cH25S6cfOhNXdueQ
# fetching and inserting business XDv71A1J3aIOu_W5sVzZ2w
# fetching and inserting business xEDD2ScBU3jHhWxlMC7dkQ
# fetching and inserting business Xf6e3HaP0AgMBxY7dEDkOA
# fetching and inserting business XfHgiIsoo1Pr_v04bx9ptg
# fetching and inserting business xFp3xSQ43J-i7nmJfNBsZA
# fetching and inserting business xH7mEjh4Rn6KdHjXYNoOjw
# fetching and inserting business xi_QX5uArqDM4LeL4WIv1Q
# fetching and inserting business XiIBASyS65DX3E_staW0JQ
# fetching and inserting business xkfkmYkunRm514wt7Z_cVQ
# fetching and inserting business XkL6fOBtaIqVCMXVCY9row
# fetching and inserting business xLJnT-pB4VECJzmUf1Whpg
# fetching and inserting business XmycF9-fpEPlgMe8_qgJrQ
# fetching and inserting business XoJwcOxazBKvWikQCATS-w
# fetching and inserting business XOnspIaW6mYVmrvgqOaYSQ
# fetching and inserting business XoxEVVf5Ci8nibQ-Q4P0nQ
# fetching and inserting business XpPkW8XPNTOrrX7zkXJrFw
# fetching and inserting business xq0cX_DgxiJMXwhmEl9kUA
# fetching and inserting business xrnk8mgoV7up6fauVmugpw
# fetching and inserting business xscOfj1dMkEKvhrRruLpIg
# fetching and inserting business xSY8MI449l9HvKJKBSlVHA
# fetching and inserting business XtS0NsI3eheyr5FjEvwluw
# fetching and inserting business xtxcAUvrD4dWHJd0cwvW1A
# fetching and inserting business xVduej7-JiPrZzsFXIkIDw
# fetching and inserting business xVPTI1ytXt2PLU-strKcnw
# fetching and inserting business XW3hRkVoOqNu2xRBienBNw
# fetching and inserting business xWUL-j6TQyKQHIfOtetu-Q
# fetching and inserting business xymropCDcEvCYGKC0AKe-w
# fetching and inserting business xZ96vaoL-cQjfotmUKtjJQ
# fetching and inserting business XzMVQtnifzlFoq6Uj4795g
# fetching and inserting business XZswR1A0FMc3LZ-TmB8OYg
# fetching and inserting business y_ylOQzCP-9D_4DcUIJ3jA
# fetching and inserting business y-c0jyeEoCotVLPrT8iI7A
# fetching and inserting business Y1s36Tk63HIzAc76X_fAiQ
# fetching and inserting business y8JSKjpWeQg8vzm5wovOwQ
# fetching and inserting business Y92VtOkTZ6BirkJbUKCMOw
# fetching and inserting business ya4nQkuVH1ZnmNp9m1yISg
# fetching and inserting business Yb6PQ_4YQpJ0SVZ1tetkbg
# fetching and inserting business YC-wGlO0oOkEIaCEDZv-ag
# fetching and inserting business YCen62jqSWhPOAorQjSZdQ
# fetching and inserting business YdAtCf_13UK-uvXuOMrhNg
# fetching and inserting business yDS7SUTAe6y3BYKdepIrbg
# fetching and inserting business ye-TSU-mu1Gd5TAJOpI5Mg
# fetching and inserting business YGdl5Bb2ONrtixvgv1P26g
# fetching and inserting business YGfpddz2ml_2h75wbzkh2A
# fetching and inserting business yhiH0hkO_RJ6cwEbuHFT7w
# fetching and inserting business YIwYw_A_LRwK66HBTzogYQ
# fetching and inserting business Yj3pRPnIG05AjRfGP0Afjg
# fetching and inserting business yj9vVa08ABH6BBOLHMfJag
# fetching and inserting business YKsHo3V-PkeRQdLYOdG7ZA
# fetching and inserting business ynB8T3htx8s5V0YV8gVPGA
# fetching and inserting business ynIx549QFj29o84y1RSGyw
# fetching and inserting business yNk043q6XT2HmiL_CcJqVQ
# fetching and inserting business YoGcGxo9JxE7NtmMtPaNng
# fetching and inserting business ySIIdmS4oh-QL2dny7GscA
# fetching and inserting business yUVcpgecpq1qncpa1x34Hg
# fetching and inserting business yVcsizod8r1-nqCBF4QdpA
# fetching and inserting business yvdaxotCYEt9HNt7GbERJw
# fetching and inserting business YvMLbSK_tWmaOjYGwOUd5Q
# fetching and inserting business YY-qRDgWpHM4Rf7PZ2zwmw
# fetching and inserting business yYb0d4LHFgH65KZeKuxwpQ
# fetching and inserting business YzyHW3w0HUyaG8EvplNT1A
# fetching and inserting business Z0VCrAW4VKIL7SteB6w8Mw
# fetching and inserting business Z263fPuSX3B3xNE7izgirw
# fetching and inserting business z6HMM_cSraJFkQFvSjWGDA
# fetching and inserting business z6WBXksrh0FQXYCPr2nnFg
# fetching and inserting business Z9t-ou4JhiBu-n4-F7hDng
# fetching and inserting business za9mYaRVWkwKkQfjRgvU0g
# fetching and inserting business zb78ua-FlfFRj8v082giBw
# fetching and inserting business ZCAkVl5SeCDeBWg_xjfYeg
# fetching and inserting business ZdLS7gD1ulmCPkqNc9_S3A
# fetching and inserting business zdX9mwhoknXXYL1GCstnow
# fetching and inserting business zEIt0xaPM9DIS-pc118O6A
# fetching and inserting business zI4TdT-Y7yAue0VN2LfUKg
# fetching and inserting business ZIdrU1MPCJkVhGILjA2D2A
# fetching and inserting business ZiGeqmXH55hVegpqnqoznw
# fetching and inserting business zj4vqgljRhxwWlvttgFRKQ
# fetching and inserting business znB_ZvfFDJWjqYFzuGV8qg
# fetching and inserting business zPK48x2wvTmJTQ_13bbeRQ
# fetching and inserting business zqyGYIiCXL1Hz8KVZxbylQ
# fetching and inserting business zrjxk9o02-fs-hMcrAyaRQ
# fetching and inserting business zrV2yUsz1SxymeH51iRBRw
# fetching and inserting business zubN8Ve-RyoljRZV4NRxEQ
# fetching and inserting business zuD-iB7hV_dnf_JzBk_DCQ
# fetching and inserting business ZwSGKO5hy4tbW6528qEgkQ
# fetching and inserting business Zx44jCgDv1TwKMGzcXajIQ
# fetching and inserting business ZybTcEwBUeQqiiyyBpoiPQ
# fetching and inserting business zyG1GIU3KnIZ3bOVGgJXlA
# fetching and inserting business zYoL-o9YJpGTwJ-Gmj8AFA
# fetching and inserting business ZYWwYSXWyDlVYIjPgXmIQA
# fetching and inserting business zZecd370h2jxzh1kRJ4y2g

# %%
db_insert(cnx, cursor, review_tuple)

# %%
#variable for one business reviews

review_ids[0][0]
# Out:
# {'id': 'PqQBDlivLjcp3ZpB3u8iQg',
#  'url': 'https://www.yelp.com/biz/j-j-chans-garden-east-elmhurst?adjust_creative=NTOFq0hWesFzHYCprBXMFw&hrid=PqQBDlivLjcp3ZpB3u8iQg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=NTOFq0hWesFzHYCprBXMFw',
#  'text': "Not a bad place. Get plenty of food customer service could be better. They just weren't happy to serve you. They have a order to go station to if you don't...",
#  'rating': 4,
#  'time_created': '2019-08-24 14:56:56',
#  'user': {'id': '01OWCk1-LcDVX3NsOpUhZA',
#   'profile_url': 'https://www.yelp.com/user_details?userid=01OWCk1-LcDVX3NsOpUhZA',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/h2r9BBNvK5FqMGHEckF5Zg/o.jpg',
#   'name': 'Kristian A.'}}

# %%
# write a function that takes a business id 
# and makes a call to the API for reivews

def parse_reviews(business_reviews):
    review_tuple_list = []
    for review in business_reviews:
        review_tuple = (review['text'],
                        review['time_created'],
                        review['id'],
                        
                        
        )

# %%
# Write a function to parse out the relevant information from the reviews

for

# %%
# write a function to insert the parsed data into the reviews table

# %%
# combine the functions above into a single script

# %% [markdown]
# ## Part 5 -  Write SQL queries that will answer the questions posed.
#
# Now that your data is in the DB, you can answer the questions. Write SQL querires that will answer the questions. **Do not use Pandas in this lab**

# %%
# create connection

# %%
# execute SQL queries

# %% [markdown]
# # Extra Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
def yelp_call(url_params, api_key):
    # your code to make the yelp call
    response = requests.get(url, headers=headers, params=url_params )
    data = response.json()
    business_data = data['businesses']
    return business_data

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    business_tuple_list = []
    for business in results:
        business_rev = business.get('price', 'No Price Listed')
        business_tuple = (business['name'],
                            business['location']['city'],
                            business['review_count'],
                            business['rating'],
                            business_rev,
                            business['id'])

        business_tuple_list.append(business_tuple)
    return business_tuple_list

# %%
def db_insert(cnx, cursor, parsed_results):
    # your code to insert and commit the results
    cursor.executemany(insert_statement, parsed_results)
    cnx.commit()
    # I would create the connection and cursor outside of this function and then pass it through

# %%
# create a variable  to keep track of which result you are in. 
cur = 0
parsed_final = []
#set up a while loop to go through and grab the result 
while cur  < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    #add list of tuples to a final list
    parsed_final.extend(parsed_results)
    
    # use your function to insert your parsed results into the db
#     db_insert(cnx, cursor, parsed_results)
#     increment the counter by 50 to move on to the next results
    cur += 50

# %%
# parsed_final

# %%
# db_insert(cnx, cursor, parsed_final)

# %%
cnx.close()
