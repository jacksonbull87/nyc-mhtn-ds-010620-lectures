# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# For this lab you will analyze the yelp data for a group of businesses to learn more about an industry. You will choose a type of business (Italian Restuarants, Nail Salons, Crossfit gyms) and a location to analyze. Then you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer questions about the data.
#
#
# ### Process:
#
# 1. Read through the SQL questions and the API documentation to determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create code to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
#
# ## SQL Questions:
#
# - Which are the 5 most reviewed businesses?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - Return the text of the reviews for the most reviewed restaurant.
# - Return the name of the business with the most recent review.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# Lok at the question and determine what data you will need to store in your database in order to answer the questions. Start to thin about your DB schema. What tables will you want to create and what columns will you ahve for those tables.
#
# Look at the API documentation, and determine what fields of the API response you will match up with the columns you want in your DB tables.
#
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ## Part 2 - Set up the DB
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %% [markdown]
# ### Foriegn Keys
#
# For this project you will have two tables that you need to link using a foreign key. Below is some information about how to create a foriegn key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/

# %% [markdown]
# ### Using DB:
#
# For this lab, you can either store the data on one DB or put in on both of the partners DBs. If you decide to put it on one DB, you want to make sure both partners have access to it.  To do this you want to add a user to your DB.
#
# [how to add a new user](https://howchoo.com/g/mtm3zdq2nzv/how-to-add-a-mysql-user-and-grant-privileges)

# %%
## Connect to DB server on AWS
# make sure we have the package installed
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading https://files.pythonhosted.org/packages/f5/8a/a0d761dbe19f16bbf23b80cc0f66fe00a3218e7dfc6aa12cb1a9a881de33/mysql_connector_python-8.0.19-cp36-cp36m-macosx_10_14_x86_64.whl (4.8MB)
#      |████████████████████████████████| 4.8MB 2.3MB/s eta 0:00:01
# Collecting dnspython==1.16.0 (from mysql-connector-python)
#   Downloading https://files.pythonhosted.org/packages/ec/d3/3aa0e7213ef72b8585747aa0e271a9523e713813b9a20177ebe1e939deb0/dnspython-1.16.0-py2.py3-none-any.whl (188kB)
#      |████████████████████████████████| 194kB 9.7MB/s eta 0:00:01
# Collecting protobuf==3.6.1 (from mysql-connector-python)
#   Downloading https://files.pythonhosted.org/packages/c7/27/133f225035b9539f2dcfebcdf9a69ff0152f56e0120160ec5c972ea7deb9/protobuf-3.6.1-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 19.0MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/flatironschool/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from protobuf==3.6.1->mysql-connector-python) (41.2.0)
# Requirement already satisfied: six>=1.9 in /Users/flatironschool/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from protobuf==3.6.1->mysql-connector-python) (1.12.0)
# Installing collected packages: dnspython, protobuf, mysql-connector-python
#   Found existing installation: protobuf 3.8.0
#     Uninstalling protobuf-3.8.0:
#       Successfully uninstalled protobuf-3.8.0
# Successfully installed dnspython-1.16.0 mysql-connector-python-8.0.19 protobuf-3.6.1

# %%
import config

# %%
import mysql.connector
cnx = mysql.connector.connect(
                            host=config.mycred['host'],
                            user=config.mycred['user'],
                            password=config.mycred['password'],
                            port=config.mycred['port'],
                            database='Yelp_Business'

)

cursor = cnx.cursor()

# %%
## Create new DB 

cursor.execute('''CREATE DATABASE Yelp_Business;
''')

# %%
# Create a table for the Businesses

#Columns: Name (string), Location(string), Review_Count (INT), Rating (FLoat), Price(String), Business_ID(string) (Primary Key)

cursor.execute('''CREATE TABLE Businesses (
                                Name varchar(255),
                                Location varchar(255),
                                Review_Count int,
                                Rating float,
                                Price varchar(255),
                                Business_ID varchar(255) NOT NULL,
                                PRIMARY KEY (Business_ID)
)

;

'''

)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488                                raw=raw, buffered=buffered,
# --> 489                                raw_as_string=raw_as_string)
#     490         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: A table must have at least 1 column
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-12-2c4b49701919> in <module>
#       3 cursor.execute('''CREATE TABLE Businesses;
#       4
# ----> 5 '''
#       6
#       7 )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/mysql/connector/cursor_cext.py in execute(self, operation, params, multi)
#     264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#     268             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/mysql/connector/connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     490         except MySQLInterfaceError as exc:
#     491             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 492                                              sqlstate=exc.sqlstate)
#     493         except AttributeError:
#     494             if self._unix_socket:
#
# ProgrammingError: 1113 (42000): A table must have at least 1 column

# %%
# Create a table for the Businesses

# Create a table for the Businesses

#Columns: Name (string), Location(string), Review_Count (INT), Rating (FLoat), Price(String), Business_ID(string) (Primary Key)

cursor.execute('''CREATE TABLE Businesses (
                                Name varchar(255),
                                Location varchar(255),
                                Review_Count int,
                                Rating float,
                                Price varchar(255),
                                Business_ID varchar(255) NOT NULL,
                                PRIMARY KEY (Business_ID)
)

;

'''

)

# %% [markdown]
# ## Part 3 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %%
# Write a function to make a call to the yelp API

import requests

url = 'https://api.yelp.com/v3/businesses/search'
api_key = 'Gh_Hoaof6K6gvy1HxSSBhy4Y0wwwFvIPKgC00UWhvCvkeVhJStATKWD-eMbwilkXhjcdDiqCI3ZBYxfq0nV6CvpGhz4T9VPCFgLDH2B54eqTff1-a7PQd9fR7kHpXXYx'

headers = {'Authorization': 'Bearer {}'.format(api_key),
    
    
}

term = 'chinese restaurant'

location = 'New York City'

limit = 50

offset = 50

url_params = {'term': 'chinese restaurant'.replace(' ', '+'),
              'location': 'New York City'.replace(' ', '+'),
              'limit': 50,
              'offset': 50
    
}

def call_yelp_data(url,headers, url_params):
    response = requests.get(url, headers=headers, params=url_params )
    data = response.json()
    print(data)
    business_data = data['businesses']
    return business_data
    `

# %%
business_data = call_yelp_data(url,headers, url_params)
# Out:
# {'businesses': [{'id': 'Q1TpfbuPwKPFrNFyu-u2_g', 'alias': 'han-dynasty-brooklyn-2', 'name': 'Han Dynasty', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxbMumdu8Q1e3iCxJ2qZfQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/han-dynasty-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 260, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.0, 'coordinates': {'latitude': 40.6911319610036, 'longitude': -73.9825977757573}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1 Dekalb Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11201', 'country': 'US', 'state': 'NY', 'display_address': ['1 Dekalb Ave', 'Brooklyn, NY 11201']}, 'phone': '+17188580588', 'display_phone': '(718) 858-0588', 'distance': 1872.1778710541835}, {'id': 'ynB8T3htx8s5V0YV8gVPGA', 'alias': '21-shanghai-house-new-york-4', 'name': '21 Shanghai House', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JTTk7-6DC-xGzthdKRK4CA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/21-shanghai-house-new-york-4?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 428, 'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}, {'alias': 'dimsum', 'title': 'Dim Sum'}], 'rating': 4.0, 'coordinates': {'latitude': 40.7140138244835, 'longitude': -73.9964454932541}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '21 Division St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10002', 'country': 'US', 'state': 'NY', 'display_address': ['21 Division St', 'New York, NY 10002']}, 'phone': '+12122268998', 'display_phone': '(212) 226-8998', 'distance': 969.9399795414205}, {'id': 'l44CFBTejwL0ElKmkH7xQQ', 'alias': 'decoy-new-york', 'name': 'Decoy', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rjt-2j5S49CZIeXKFU3THw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/decoy-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 422, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 40.734196, 'longitude': -74.006519}, 'transactions': [], 'price': '$$$', 'location': {'address1': '529 Hudson St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10014', 'country': 'US', 'state': 'NY', 'display_address': ['529 Hudson St', 'New York, NY 10014']}, 'phone': '+12126919700', 'display_phone': '(212) 691-9700', 'distance': 3358.90607968442}, {'id': 'rEbwps11tIERRkwQrIXQog', 'alias': 'hakkasan-new-york', 'name': 'Hakkasan', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dQLq-Mg9HRkTyg-pl2iJnQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 909, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 3.5, 'coordinates': {'latitude': 40.758619, 'longitude': -73.989961}, 'transactions': [], 'price': '$$$', 'location': {'address1': '311 W 43rd St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10036', 'country': 'US', 'state': 'NY', 'display_address': ['311 W 43rd St', 'New York, NY 10036']}, 'phone': '+12127761818', 'display_phone': '(212) 776-1818', 'distance': 5923.944856973323}, {'id': 'ikx8R8u2lmxhpLGByCjgPw', 'alias': 'house-special-甘來飯店-new-york', 'name': 'House Special 甘來飯店', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PO0lvtD9QTXh1Bt0j-S9mA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/house-special-%E7%94%98%E4%BE%86%E9%A3%AF%E5%BA%97-new-york?adjust_creative=NTOFq ...

# %%
data = response.json()

# %%
data['businesses']
# Out:
# [{'id': '0CjK3esfpFcxIopebzjFxA',
#   'alias': 'joes-shanghai-new-york-2',
#   'name': "Joe's Shanghai",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 6089,
#   'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7156608, 'longitude': -73.9967012},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '46 Bowery St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['46 Bowery St', 'New York, NY 10013']},
#   'phone': '+12122338888',
#   'display_phone': '(212) 233-8888',
#   'distance': 1153.9482385806896},
#  {'id': '0dDCDQz7DrKkSvu9h2hcQw',
#   'alias': 'chow-house-new-york',
#   'name': 'Chow House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kzeClsI9_2tkHqKScotx1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chow-house-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 367,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72915, 'longitude': -74.00072},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '181 Bleecker St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['181 Bleecker St', 'New York, NY 10012']},
#   'phone': '+12128371021',
#   'display_phone': '(212) 837-1021',
#   'distance': 2692.4401801037266},
#  {'id': 'wfhMIiMh2A2psCGONOVSlg',
#   'alias': 'han-dynasty-new-york',
#   'name': 'Han Dynasty',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/51xeXIccNqqhVHwTYPu3Ig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/han-dynasty-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 1223,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.732072, 'longitude': -73.988074},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '90 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90 3rd Ave', 'New York, NY 10003']},
#   'phone': '+12123908685',
#   'display_phone': '(212) 390-8685',
#   'distance': 3006.833804957513},
#  {'id': 'xq0cX_DgxiJMXwhmEl9kUA',
#   'alias': 'café-china-new-york-2',
#   'name': 'Café China',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UhHqxEX2epOvrBFI2pgRzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caf%C3%A9-china-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 1604,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7499225208569,
#    'longitude': -73.9819464127197},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '13 E 37th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['13 E 37th St', 'New York, NY 10016']},
#   'phone': '+12122132810',
#   'display_phone': '(212) 213-2810',
#   'distance': 5053.933662238418},
#  {'id': '6tASYtO9zOrXr8-LPnAToQ',
#   'alias': 'zest-szechuan-new-york',
#   'name': 'Zest Szechuan',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gRwi2bF4FXIZKHgFObryqA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zest-szechuan-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 573,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75274, 'longitude': -73.98445},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '45 W 39th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['45 W 39th St', 'New York, NY 10018']},
#   'phone': '+16468700521',
#   'display_phone': '(646) 870-0521',
#   'distance': 5323.221187222823},
#  {'id': '0k678lCWQyReNi0lARlOmw',
#   'alias': 'china-blue-new-york',
#   'name': 'China Blue',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wUyWKSI3tZNtC6FOwTGHtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-blue-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 695,
#   'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.724038, 'longitude': -74.009958},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '135 Watts St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['135 Watts St', 'New York, NY 10013']},
#   'phone': '+12124310111',
#   'display_phone': '(212) 431-0111',
#   'distance': 2453.053993492216},
#  {'id': 'qrncvjkiKN5Z-JC06ygy6A',
#   'alias': 'hutong-new-york',
#   'name': 'Hutong',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jyrAnQ9Lt8OdQgL2uYqO-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hutong-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 257,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.761551, 'longitude': -73.967443},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '731 Lexington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10022',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['731 Lexington Ave', 'New York, NY 10022']},
#   'phone': '+12127584800',
#   'display_phone': '(212) 758-4800',
#   'distance': 6636.244354302038},
#  {'id': 'ojbH3wnRu050hRhkmoxRiA',
#   'alias': 'han-dynasty-new-york-4',
#   'name': 'Han Dynasty',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fe5QaNZH6Qc-dbIDPwE2Ww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/han-dynasty-new-york-4?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 588,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.78752, 'longitude': -73.97647},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '215 W 85th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['215 W 85th St', 'New York, NY 10024']},
#   'phone': '+12128589060',
#   'display_phone': '(212) 858-9060',
#   'distance': 9254.42805459871},
#  {'id': 'lynQoI3w_pzYfHGeuUU-Qg',
#   'alias': 'shu-jiao-fu-zhou-cuisine-restaurant-new-york',
#   'name': 'Shu Jiao Fu Zhou Cuisine Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EV10p_mweh7C1qjrLUJePw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shu-jiao-fu-zhou-cuisine-restaurant-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 817,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7184290357839,
#    'longitude': -73.9916928979573},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '118 Eldridge St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['118 Eldridge St', 'New York, NY 10002']},
#   'phone': '+12126252532',
#   'display_phone': '(212) 625-2532',
#   'distance': 1460.3128603386444},
#  {'id': 'ZCAkVl5SeCDeBWg_xjfYeg',
#   'alias': 'clay-pot-east-village-new-york-2',
#   'name': 'Clay Pot - East Village',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3sfoNZ7LD5w7X9EyWLZVyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/clay-pot-east-village-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 307,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7279880270274,
#    'longitude': -73.9865907985248},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': "58 St Mark's Pl",
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ["58 St Mark's Pl", 'New York, NY 10003']},
#   'phone': '+16464346449',
#   'display_phone': '(646) 434-6449',
#   'distance': 2589.374386720123},
#  {'id': '37mIbgT7_GTDt9ZBYjs6nw',
#   'alias': 'teriyaki-burrito-house-brooklyn-5',
#   'name': 'Teriyaki Burrito House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z13Kynn-MFB53UuQGYo_5w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/teriyaki-burrito-house-brooklyn-5?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 40,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'poke', 'title': 'Poke'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.68965, 'longitude': -73.97899},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '96 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['96 Dekalb Ave', 'Brooklyn, NY 11201']},
#   'phone': '+17187224771',
#   'display_phone': '(718) 722-4771',
#   'distance': 2171.152748332856},
#  {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#   'alias': 'wah-fung-no-1-fast-food-new-york-3',
#   'name': 'Wah Fung No 1 Fast Food',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 1384,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '79 Chrystie St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#   'phone': '+12129255175',
#   'display_phone': '(212) 925-5175',
#   'distance': 1323.2851807067286},
#  {'id': 'FXhSEZfIqjMZh4hR0_8jMQ',
#   'alias': 'china-xiang-中国湘-new-york-2',
#   'name': 'China Xiang 中国湘',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MC6-poc5wb7mP-jO7qfHHw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-xiang-%E4%B8%AD%E5%9B%BD%E6%B9%98-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 462,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7582902125633,
#    'longitude': -73.9925113993899},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '360 W 42nd Street',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['360 W 42nd Street', 'New York, NY 10036']},
#   'phone': '+12129676088',
#   'display_phone': '(212) 967-6088',
#   'distance': 5878.045777624759},
#  {'id': 'croh2zWlbPyCQTNS11klcg',
#   'alias': 'china-river-川聚院-new-york-3',
#   'name': 'China River 川聚院',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dRkUvUBe_DhvneTqBw5Khg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-river-%E5%B7%9D%E8%81%9A%E9%99%A2-new-york-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 187,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7581711239604,
#    'longitude': -73.9883149042726},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '258 W 44th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['258 W 44th St', 'New York, NY 10036']},
#   'phone': '+16467670854',
#   'display_phone': '(646) 767-0854',
#   'distance': 5884.486473885884},
#  {'id': 'MaZWYgvu08NLQVRcDGGvqQ',
#   'alias': 'zhen-wei-fang-new-york',
#   'name': 'Zhen Wei Fang',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wYvZ6PaFNqtIgZoTDCSabg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zhen-wei-fang-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 182,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72128, 'longitude': -73.99343},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'location': {'address1': '207 Bowery',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['207 Bowery', 'New York, NY 10002']},
#   'phone': '+16467670355',
#   'display_phone': '(646) 767-0355',
#   'distance': 1760.566981584637},
#  {'id': 'bVkjBJlAIwKAj9Aw1KVWjA',
#   'alias': 'dim-sum-palace-new-york-8',
#   'name': 'Dim Sum Palace',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CaAY18TnjUce10XYC3zcgA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dim-sum-palace-new-york-8?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 1218,
#   'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76015, 'longitude': -73.9893699},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '334 W 46th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['334 W 46th St', 'New York, NY 10036']},
#   'phone': '+16468611910',
#   'display_phone': '(646) 861-1910',
#   'distance': 6102.3266274330845},
#  {'id': 'i6RhqnCJ_oUfTu5LikGXUg',
#   'alias': 'dun-huang-east-village-new-york-8',
#   'name': 'Dun Huang - East Village',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y52pjx_ZEbdkB4LEWoMedQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dun-huang-east-village-new-york-8?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 322,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73081, 'longitude': -73.98568},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '300 E 12th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['300 E 12th St', 'New York, NY 10003']},
#   'phone': '+12122543817',
#   'display_phone': '(212) 254-3817',
#   'distance': 2908.2544225724664},
#  {'id': 'sfsjk1h50ooC2ioY7m48gw',
#   'alias': 'pig-heaven-new-york-3',
#   'name': 'Pig Heaven',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YzHJPPxM5m6qp_vwfrC6SA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pig-heaven-new-york-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 379,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.77544, 'longitude': -73.95686},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1420 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10028',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1420 3rd Ave', 'New York, NY 10028']},
#   'phone': '+12127444333',
#   'display_phone': '(212) 744-4333',
#   'distance': 8399.490329439157},
#  {'id': 'oowNI_aUmGEFa_VW8BFgRg',
#   'alias': 'tri-dim-shanghai-new-york-2',
#   'name': 'Tri Dim Shanghai',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-HycyO1XNiKGN8q28RYATg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tri-dim-shanghai-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 379,
#   'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.77395, 'longitude': -73.95793},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1378 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10075',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1378 3rd Ave', 'New York, NY 10075']},
#   'phone': '+12125853388',
#   'display_phone': '(212) 585-3388',
#   'distance': 8209.867326951198},
#  {'id': 'qH8PVeddtVs9cKN2pwgdkQ',
#   'alias': 'hwa-yuan-new-york-2',
#   'name': 'Hwa Yuan',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FUlrT0L-7WXks3aqekdAhQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hwa-yuan-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#   'review_count': 258,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7137, 'longitude': -73.99598},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$$',
#   'location': {'address1': '42 E Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['42 E Broadway', 'New York, NY 10002']},
#   'phone': '+12129666002',
#   'display_phone': '(212) 966-6002',
#   'distance': 936.1140589682508}]

# %%
len(business_data)
# Out:
# 50

# %%
data['businesses'][19]['price']
# Out:
# '$$$'

# %%
def call_yelp_data(url,headers, url_params):
    response = requests.get(url, headers=headers, params=url_params )
    data = response.json()
    print(data)
    business_data = data['businesses']
    return business_data

# %%
business_data = call_yelp_data(url,headers, url_params)
# Out:
# {'businesses': [{'id': 'Q1TpfbuPwKPFrNFyu-u2_g', 'alias': 'han-dynasty-brooklyn-2', 'name': 'Han Dynasty', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vxbMumdu8Q1e3iCxJ2qZfQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/han-dynasty-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 260, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 4.0, 'coordinates': {'latitude': 40.6911319610036, 'longitude': -73.9825977757573}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '1 Dekalb Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11201', 'country': 'US', 'state': 'NY', 'display_address': ['1 Dekalb Ave', 'Brooklyn, NY 11201']}, 'phone': '+17188580588', 'display_phone': '(718) 858-0588', 'distance': 1872.1778710541835}, {'id': 'ynB8T3htx8s5V0YV8gVPGA', 'alias': '21-shanghai-house-new-york-4', 'name': '21 Shanghai House', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JTTk7-6DC-xGzthdKRK4CA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/21-shanghai-house-new-york-4?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 428, 'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}, {'alias': 'dimsum', 'title': 'Dim Sum'}], 'rating': 4.0, 'coordinates': {'latitude': 40.7140138244835, 'longitude': -73.9964454932541}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '21 Division St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10002', 'country': 'US', 'state': 'NY', 'display_address': ['21 Division St', 'New York, NY 10002']}, 'phone': '+12122268998', 'display_phone': '(212) 226-8998', 'distance': 969.9399795414205}, {'id': 'l44CFBTejwL0ElKmkH7xQQ', 'alias': 'decoy-new-york', 'name': 'Decoy', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rjt-2j5S49CZIeXKFU3THw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/decoy-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 422, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 40.734196, 'longitude': -74.006519}, 'transactions': [], 'price': '$$$', 'location': {'address1': '529 Hudson St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10014', 'country': 'US', 'state': 'NY', 'display_address': ['529 Hudson St', 'New York, NY 10014']}, 'phone': '+12126919700', 'display_phone': '(212) 691-9700', 'distance': 3358.90607968442}, {'id': 'rEbwps11tIERRkwQrIXQog', 'alias': 'hakkasan-new-york', 'name': 'Hakkasan', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dQLq-Mg9HRkTyg-pl2iJnQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hakkasan-new-york?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw', 'review_count': 909, 'categories': [{'alias': 'chinese', 'title': 'Chinese'}], 'rating': 3.5, 'coordinates': {'latitude': 40.758619, 'longitude': -73.989961}, 'transactions': [], 'price': '$$$', 'location': {'address1': '311 W 43rd St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10036', 'country': 'US', 'state': 'NY', 'display_address': ['311 W 43rd St', 'New York, NY 10036']}, 'phone': '+12127761818', 'display_phone': '(212) 776-1818', 'distance': 5923.944856973323}, {'id': 'ikx8R8u2lmxhpLGByCjgPw', 'alias': 'house-special-甘來飯店-new-york', 'name': 'House Special 甘來飯店', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PO0lvtD9QTXh1Bt0j-S9mA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/house-special-%E7%94%98%E4%BE%86%E9%A3%AF%E5%BA%97-new-york?adjust_creative=NTOFq ...

# %%
business_data[4].keys()
# Out:
# dict_keys(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'location', 'phone', 'display_phone', 'distance'])

# %%
for business in business_data:
    for key, value in business.items():
        print(key)
    
#         business_tuple = (business['price'])
# #                           business['location']['city'],
# #                           business['review_count'],
# #                           business['rating'],
# #                           business['price'],
# #                           business['id'])
#         print(business_tuple)
# Out:
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance

# %%
# write a function to parse the API response 
# so that you can easily insert the data in to the DB

def parse_data(business_data):
    business_tuple_list = []
    for business in business_data:
        #skip business if no key doesn't exist
    
        business_tuple = (business['name'],
                          business['location']['city'],
                          business['review_count'],
                          business['rating'],
                          business['price'],
                          business['id'])
        business_tuple_list.append(business_tuple)
    return business_tuple_list

# %%
parse_data(business_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-2b1fe8884a22> in <module>
# ----> 1 parse_data(business_data)
#
# <ipython-input-94-ba7649f37e6f> in parse_data(business_data)
#      10                           business['review_count'],
#      11                           business['rating'],
# ---> 12                           business['price'],
#      13                           business['id'])
#      14         business_tuple_list.append(business_tuple)
#
# KeyError: 'price'

# %%
# Write a function to take your parsed data and insert it into the DB

# %%
# Write a script that combines the three functions above into a single process.

# %% [markdown]
# ## Part 4 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews.

# %%
# write a SQL query to pull back all of the business ids 
# you will need these ids to pull back the reviews for each restaurant

# %%
# write a function that takes a business id 
# and makes a call to the API for reivews

# %%
# Write a function to parse out the relevant information from the reviews

# %%
# write a function to insert the parsed data into the reviews table

# %%
# combine the functions above into a single script

# %% [markdown]
# ## Part 5 -  Write SQL queries that will answer the questions posed.
#
# Now that your data is in the DB, you can answer the questions. Write SQL querires that will answer the questions. **Do not use Pandas in this lab**

# %%
# create connection

# %%
# execute SQL queries

# %% [markdown]
# # Extra Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
def yelp_call(url_params, api_key):
    # your code to make the yelp call
    return data

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    return parsed_results

# %%
def db_insert(cnx, cursor, parsed results):
    # your code to insert and commit the results
    # I would create the connection and cursor outside of this function and then pass it through

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50
